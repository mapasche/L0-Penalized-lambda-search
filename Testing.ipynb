# %%
import numpy as np
import cvxpy as cp 
from queue import Queue
from copy import deepcopy
from time import sleep
from BnB_normal import BnBNormalAlgorythm
import pandas as pd

# %%
A = np.matrix([[1, 2, 3],[3, 4, 3],[2, 1, 0]])
B = np.matrix([[1, 2, 3],[3, 4, 3],[2, 1, 0]])
x = np.array([1,0,0.5])
y = np.matrix([3,4,5]).T
np.linalg.norm(x)
np.count_nonzero(x)
lambda_0 = 1
M0 = 10000
A @ B
# Out:
# matrix([[13, 13,  9],
#         [21, 25, 21],
#         [ 5,  8,  9]])

# %%
A @ x
# Out:
# matrix([[2.5, 4.5, 2. ]])

# %% [markdown]
# # We want to solve the following
#
# $$\min_{x \in \real^n} \frac{1}{2} ||y - A x||^2_2 + \lambda ||x||_0$$

# %%
def evaluation_main (y, A, x, alpha = lambda_0):
    value = 0.5 * np.linalg.norm( y - A @ x ) ** 2 + alpha * np.count_nonzero(x)    
    return value

# %%
evaluation_main(y, A, x)
# Out:
# 14.749999999999998

# %% [markdown]
# # We are going to create a BnB of the following
#
# $$\min_{x \in \real^n} \frac{1}{2} ||y - A x||^2_2 + \frac{\lambda}{M} ||x_{\bar{S}}||_1 + \lambda |S_1|$$

# %%
np.random.seed(421)
A = np.random.randint(-10, 10, (10, 10))
y = np.random.randint(-10, 10, (10, 1))
n = y.shape[0]
n
# Out:
# 10

# %%
lambda_0 = 1
M0 = 100


def evaluation_main (y, A, x, alpha = lambda_0):
    value = 0.5 * np.linalg.norm( y - A @ x ) ** 2 + alpha * np.count_nonzero(x)    
    return value


def check_bound(u, v):
    if v.pu <= u.pu:
        return v.pu, v
    else:
        return u.pu, u
    



def relax_problem (y, A, S0, S1, S, alpha = lambda_0, M = M0):
    n = y.shape[0]
    X = cp.Variable((n, 1))
    obj =  0.5 * cp.sum_squares(y - A @ X ) 
    obj +=  alpha / M * cp.norm(X[S], 1)
    obj += alpha * len(S1)

    
    if len(S0) == 0:
        constraint = [X <= M, -X <= M] 
    else:
        constraint = [X[S0] == 0, X <= M, -X <= M] 

    prob = cp.Problem(cp.Minimize( obj ), constraint)
    result = prob.solve(verbose = False, solver = cp.ECOS, abstol=1e-4, reltol=1e-4)
    
    #eliminate 0
    x_vector = X.value
    x_vector = np.where(abs(x_vector) < 1e-7, 0, x_vector )
    return result, x_vector



class Node:
    
    def __init__(self, n, S0, S1, S, A, y):
        self.level = n - len(S)
        self.A = A
        self.y = y
        self.S0 = S0
        self.S1 = S1
        self.S = S
        self.pvl = 0
        self.pu = None       #corresponds to obj func value in real problem with x
        self.x = None
        self.calculate_pvl()
        self.calculate_pu_x()
        
    
    def calculate_pvl (self) -> float:
        self.pvl, self.x = relax_problem(y, A, S0 = self.S0, S1 = self.S1, S = self.S)
        return self.pvl
        
    def calculate_pu_x (self) -> float:
        self.pu =  evaluation_main(y, A, self.x)
        return self.pu
        

    def __le__ (self, other) -> bool:
        return self.pvl <= other.pvl
    
    def __str__(self) -> str:
        text = f"S0: {self.S0} | S1: {self.S1} | S: {self.S}\nPvl: {self.pvl}\n\n"
        return text
    
    def __repr__(self) -> str:
        text = f"S0: {self.S0} | S1: {self.S1} | Pvl: {self.pvl}"
        return text

# %%
S = list(range(n))
S0 = []
S1 = []
u = Node(n, S0, S1, S, A, y)

# %%
S = list(range(n))
S0 = []
S1 = []

u1 = Node(n, S0, S1, S, A, y)
print(u1.x)
print(u1.calculate_pvl())
print(u1.calculate_pu_x())

S = deepcopy(u.S)
S1 = deepcopy(u.S1)
S0 = deepcopy(u.S0)

index = S.pop(0)
index2 = S.pop(0)

#None zero branch
S0.append(index)
S0.append(index2)

u2 = Node(n, S0, S1, S, A, y)

print(u1 >= u2)
print(u1.pu, u2.pu)
check_bound(u1, u2)
# Out:
# [[ 0.23170507]
#  [-0.43967887]
#  [-0.81020599]
#  [ 0.62298317]
#  [ 0.09508656]
#  [ 0.45371026]
#  [-0.08893891]
#  [ 0.82366556]
#  [-0.06056742]
#  [-1.4987601 ]]
# 0.051354165675013726
# 10.000101146445013
# False
# 10.000101146445013 22.80588833660041
# (10.000101146445013, S0: [] | S1: [] | Pvl: 0.051354165675013726)

# %% [markdown]
# ## We are going to create the order

# %%
S = list(range(n))
S0 = []
S1 = []

#crear queue
q = Queue()
u = Node(n, S0, S1, S, A, y)
q.put(u)

#optimum 
pv_opt = u.pu
node_opt = deepcopy(u)
print("first op:", pv_opt)




while not q.empty():
    
    u = q.get()
    print(f"u node: S0: {u.S0} | S1: {u.S1} | Pvl: {u.pvl}")
    
    #if the node is leaf
    if u.level == n  or len(u.S) == 0:
        continue
    
    S_v = deepcopy(u.S)
    S1_v = deepcopy(u.S1)
    S0_v = deepcopy(u.S0)
    
    index = S_v.pop(0)
    
    #None zero branch
    S1_v.append(index)
    
    v1 = Node(n, S0_v, S1_v, S_v, A, y)
    print("v1 pvl: ", v1.pvl)
    if not pv_opt <= v1.pvl:
        q.put(v1)
        print(v1.pu)             
        pv_opt, node_opt = check_bound(node_opt, v1)

        
    
    #Zero branch
    S_v = deepcopy(u.S)
    S1_v = deepcopy(u.S1)
    S0_v = deepcopy(u.S0)
    index = S_v.pop(0)
    S0_v.append(index)
    v0 = Node(n, S0_v, S1_v, S_v, A, y)
    print("V0 pvl:", v0.pvl)
    if not pv_opt <= v0.pvl:
        q.put(v0)
        print(v0.pu)             
        pv_opt, node_opt = check_bound(node_opt, v0)
    
    print("Queue:\t",list(q.queue), "\n")

    

print("Opt obj value:\t", pv_opt)
print("Optimum node:\n", node_opt )
# Out:
# first op: 10.000101146445013
# u node: S0: [] | S1: [] | Pvl: 0.051354165675013726
# v1 pvl:  1.0490305868541316
# 10.000063112047783
# V0 pvl: 0.25192521160595616
# 9.207988171831724
# Queue:	 [S0: [] | S1: [0] | Pvl: 1.0490305868541316, S0: [0] | S1: [] | Pvl: 0.25192521160595616]
#
# u node: S0: [] | S1: [0] | Pvl: 1.0490305868541316
# v1 pvl:  2.044623951208538
# 10.000047815949076
# V0 pvl: 3.137170806392232
# 11.099604311844722
# Queue:	 [S0: [0] | S1: [] | Pvl: 0.25192521160595616, S0: [] | S1: [0, 1] | Pvl: 2.044623951208538, S0: [1] | S1: [0] | Pvl: 3.137170806392232]
#
# u node: S0: [0] | S1: [] | Pvl: 0.25192521160595616
# v1 pvl:  1.2488451784407324
# 9.20798866013061
# V0 pvl: 14.854662245513893
# Queue:	 [S0: [] | S1: [0, 1] | Pvl: 2.044623951208538, S0: [1] | S1: [0] | Pvl: 3.137170806392232, S0: [0] | S1: [1] | Pvl: 1.2488451784407324]
#
# u node: S0: [] | S1: [0, 1] | Pvl: 2.044623951208538
# v1 pvl:  3.0365114934775246
# 10.000028746516655
# V0 pvl: 8.2354751769116
# 15.205751148022989
# Queue:	 [S0: [1] | S1: [0] | Pvl: 3.137170806392232, S0: [0] | S1: [1] | Pvl: 1.2488451784407324, S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246, S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116]
#
# u node: S0: [1] | S1: [0] | Pvl: 3.137170806392232
# v1 pvl:
#  4.131656120475425
# 11.099594675876057
# V0 pvl: 7.24403960969072
# 14.213992599904488
# Queue:	 [S0: [0] | S1: [1] | Pvl: 1.2488451784407324, S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246, S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116, S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072]
#
# u node: S0: [0] | S1: [1] | Pvl: 1.2488451784407324
# v1 pvl:  2.241620846789978
# 9.207979700484703
# V0 pvl: 8.955488283338461
# 15.930518324081504
# Queue:	 [S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246, S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116, S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461]
#
# u node: S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246
# v1 pvl:  4.030268578879637
# 10.000020520248443
# V0 pvl: 9.669539783003579
# Queue:	 [S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116, S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637]
#
# u node: S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116
# v1 pvl:  9.23318340951582
# V0 pvl: 9.80003684801184
# Queue:	 [S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637]
#
# u node: S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425
# v1 pvl:  5.128622963939962
# 11.09959347671162
# V0 pvl: 13.71458702828024
# Queue:	 [S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962]
#
# u node: S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072
# v1 pvl:  8.241897529293093
# 14.213992783157078
# V0 pvl: 13.22536442509883
# Queue:	 [S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093]
#
# u node: S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978
# v1 pvl:  3.236377307197531
# 9.207979055075711
# V0 pvl: 29.299768533737137
# Queue:	 [S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531]
#
# u node: S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461
# v1 pvl:  9.95114535436729
# V0 pvl: 29.65973644982753
# Queue:	 [S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531]
#
# u node: S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637
# v1 pvl:  5.029297857008413
# 10.000012784381788
# V0 pvl: 4.123086788135314
# 9.094862909336262
# Queue:	 [S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531, S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314]
#
# u node: S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962
# v1 pvl:  6.125964298536562
# 11.099594927565242
# V0 pvl: 6.985196868735027
# 11.95466200998074
# Queue:	 [S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531, S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027]
#
# u node: S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093
# v1 pvl:  9.237224869833831
# V0 pvl: 15.997998250644692
# Queue:	 [S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531, S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027]
#
# u node: S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531
# v1 pvl:  4.236144510413908
# 9.207980544623002
# V0 pvl: 3.253980649144582
# 8.225475211630343
# Queue:	 [S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582]
#
# u node: S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413
# v1 pvl:  6.02472902974682
# 10.000005029720413
# V0 pvl: 6.20798385244617
# 10.185071400331616
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617]
#
# u node: S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314
# v1 pvl:  5.119624286574462
# 9.094858032388162
# V0 pvl: 6.671244799541298
# 10.651999896282918
# Queue:	 [S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298]
#
# u node: S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562
# v1 pvl:  7.125438998969933
# 11.099588755049375
# V0 pvl: 6.153615958559417
# 10.128255208473062
# Queue:	 [S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417]
#
# u node: S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027
# v1 pvl:  7.98156644099092
# 11.954657325907387
# V0 pvl: 9.790965156719869
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092]
#
# u node: S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908
# v1 pvl:  5.232931718846851
# 9.20797409950276
# V0 pvl: 5.40554520770854
# 9.383697226801354
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854]
#
# u node: S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582
# v1 pvl:  4.250497934666535
# 8.225470262791337
# V0 pvl: 5.833703033429291
# 9.814202568666614
# Queue:	 [S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291]
#
# u node: S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682
# v1 pvl:  7.02384680448941
# 10.000010164396118
# V0 pvl: 6.207892050644231
# 9.181630652332993
# Queue:	 [S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231]
#
# u node: S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617
# v1 pvl:  7.205739481335416
# 10.185074343361357
# V0 pvl: 8.089842784920254
# 11.06313670124885
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254]
#
# u node: S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462
# v1 pvl:  6.11857492644226
# 9.094862391033383
# V0 pvl: 5.3979086493017325
# 8.371368004980898
# Queue:	 [S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325]
#
# u node: S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298
# v1 pvl:  7.667756706968763
# 10.652000977972795
# V0 pvl: 14.191219839065827
# Queue:	 [S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763]
#
# u node: S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933
# v1 pvl:  8.124114652130226
# 11.09959286592564
# V0 pvl: 7.5472940706716525
# 10.519261040671601
# Queue:	 [S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525]
#
# u node: S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417
# v1 pvl:  7.152056407958991
# 10.128257098811833
# V0 pvl: 7.2688503582354524
# 10.241521995942675
# Queue:	 [S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524]
#
# u node: S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092
# v1 pvl:  8.98091241453011
# V0 pvl: 8.090699717868512
# 11.062710743042018
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512]
#
# u node: S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851
# v1 pvl:  6.23183164669012
# 9.207978996336344
# V0 pvl: 5.533716474952211
# 8.506883132343493
# Queue:	 [S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211]
#
# u node: S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854
# v1 pvl:  6.403043279933726
# 9.383699295844487
# V0 pvl: 8.080347064548565
# 11.055145998915687
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535
# v1 pvl:  5.249432565690158
# 8.225475081549263
# V0 pvl: 4.5374916247738
# 7.510653232727817
# Queue:	 [S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738]
#
# u node: S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291
# v1 pvl:  6.830181240887354
# 9.814204080337927
# V0 pvl: 13.533073270750393
# Queue:	 [S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354]
#
# u node: S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941
# v1 pvl:  8.015589920490555
# V0 pvl: 13.141479962115891
# Queue:	 [S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354]
#
# u node: S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231
# v1 pvl:  7.198418560043731
# 9.181623004461166
# V0 pvl: 36.265748322614236
# Queue:	 [S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731]
#
# u node: S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416
# v1 pvl:  8.200492518281889
# V0 pvl: 15.112519842495688
# Queue:	 [S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731]
#
# u node: S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254
# v1 pvl:  9.082569771302381
# V0 pvl: 48.73830442017784
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731]
#
# u node: S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226
# v1 pvl:  7.110839171126247
# 9.094856161487211
# V0 pvl: 13.344039530785322
# Queue:	 [S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247]
#
# u node: S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325
# v1 pvl:  6.388854587994325
# 8.37136697195477
# V0 pvl: 45.54931471879404
# Queue:	 [S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763
# v1 pvl:  8.664103467746544
# V0 pvl: 15.315443540654618
# Queue:	 [S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226
# v1 pvl:  9.117543833227847
# V0 pvl: 12.533855652448914
# Queue:	 [S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525
# v1 pvl:  8.538960779513426
# V0 pvl: 36.14483312744454
# Queue:	 [S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991
# v1 pvl:  8.1459332217066
# V0 pvl: 21.19477322483008
# Queue:	 [S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524
# v1 pvl:  8.261452986227535
# V0 pvl: 52.31124554234554
# Queue:	 [S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512
# v1 pvl:  9.081593410693525
# V0 pvl: 48.72171205993041
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012
# v1 pvl:  7.224210235093943
# 9.207972410946489
# V0 pvl: 12.543049012592643
# Queue:	 [S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943]
#
# u node: S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211
# v1 pvl:  6.524666779033901
# 8.506881940313304
# V0 pvl: 39.30959457126145
# Queue:	 [S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901]
#
# u node: S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726
# v1 pvl:  7.398152920316563
# 9.38369649003174
# V0 pvl: 14.830106514895554
# Queue:	 [S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563]
#
# u node: S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565
# v1 pvl:  9.07337120841115
# V0 pvl: 48.22547827062198
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158
# v1 pvl:  6.241684018323019
# 8.225468663707241
# V0 pvl: 12.499918021654498
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738
# v1 pvl:  5.528403585763665
# 7.510651993544113
# V0 pvl: 45.155896179727954
# Queue:	 [S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665]
#
# u node: S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354
# v1 pvl:  7.826540292867032
# V0 pvl: 14.430525113728898
# Queue:	 [S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665]
#
# u node: S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731
# v1 pvl:  8.19832322592508
# V0 pvl: 7.198598456023529
# 8.181937513990238
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529]
#
# u node: S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247
# v1 pvl:  8.108477152813952
# V0 pvl: 7.824538191212013
# Queue:	 [S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529]
#
# u node: S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325
# v1 pvl:  7.386497768126252
# 8.371367805450843
# V0 pvl: 7.099400724458189
# 8.082635275435507
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943
# v1 pvl:  8.220798108455053
# V0 pvl: 11.0513399087742
# Queue:	 [S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901
# v1 pvl:  7.521313987166529
# V0 pvl: 10.234107079686929
# Queue:	 [S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563
# v1 pvl:  8.39372064688965
# V0 pvl: 16.516822753215735
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019
# v1 pvl:  7.238427254227806
# 8.225468551564735
# V0 pvl: 12.608313342825229
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665
# v1 pvl:  6.525122578319298
# 7.510652146141352
# V0 pvl: 11.9981491823604
# Queue:	 [S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529
# v1 pvl:  8.18193689170781
# V0 pvl: 104.97379730593653
# Queue:	 [S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252
# v1 pvl:  8.371366188736342
# V0 pvl: 42.18159158894162
# Queue:	 [S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189
# v1 pvl:  8.082634574206425
# V0 pvl: 106.53126235815321
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806
# v1 pvl:  8.225465479325454
# V0 pvl: 21.95641677008117
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298
# v1 pvl:  7.510651296502245
# 7.510651299161866
# V0 pvl: 67.37261071778417
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | Pvl: 7.510651296502245]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | Pvl: 7.510651296502245
# Opt obj value:	 7.510651299161866
# Optimum node:
#  S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | S: []
# Pvl: 7.510651296502245

# %%
np.random.seed(420)
n = 15
A = np.random.randint(-10, 10, (n, n))
y = np.random.randint(-10, 10, (n, 1))

lambda_0 = 1
M0 = 100

# %%
node = node_opt
node
# Out:
# S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | Pvl: 7.510651296502245

# %%
u = node.y -  node.A @ node.x
node.A[: , 1 ] @ u
# Out:
# array([4.60092871e-06])

# %%
for i in range(5, -1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
np.random.seed(42)
n = 8
A = np.random.randint(-10, 10, (n, n))
y = np.random.randint(-10, 10, (n, 1))

lambda_0 = 1
M0 = 100

solver = BnBNormalAlgorythm(y, A, lambda0=lambda_0, M=M0)

pv, node, num_nodes, nodes = solver.solve(verbose=False)

print("Solution Node")
# remember to count node 0
print(f"Nodes visited {num_nodes}/{2**(n) + 1}")
print(node)

print(node.x)

print("Getting lambda intervals")
node.get_lambda_interval(verbose = True)
# Out:
# Initializing normal solver BnB
# .............
#
#             ############################################################
#             	Solver finished in:	3.030752182006836 s
#             ############################################################
#
# Solution Node
# Nodes visited 99/257
# S0: [0, 1, 2, 4, 5, 6] | S1: [3, 7] | S: []
# Pvl: 2.9164648947133163
#
# [[ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [-0.90412079]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.49853023]]
# Getting lambda intervals
# []
# omega: 0.0009199701056132881
# J0: -1
# Lambda: 1
# Leaf Node
# S0: [0, 1, 2, 4, 5, 6] | S1: [3, 7] | S: []
# Pvl: 2.9164648947133163
#  [ -inf , inf ]
# (-inf, inf)

# %%
lower_bounds = []
upper_bounds = []
for node in nodes:
    lower_bound, upper_bound = node.get_lambda_interval(verbose = True)
    lower_bounds.append(lower_bound)
    upper_bounds.append(upper_bound)
# Out:
# [val : 8.0368, idx : 3, val : 8.0147, idx : 4, val : 7.9996, idx : 6, val : 7.9982, idx : 5, val : 7.9944, idx : 2, val : 7.9942, idx : 0, val : 7.9786, idx : 1, val : 7.9594, idx : 7]
# omega: -1.0893734510346533
# J0: 7
# Lambda: 1
# First interval [ -inf , 7.959414487867278 ]
# J: 7
# If Lambda* in [ -inf , 7.959414487867278 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 7
# If Lambda* in [ -inf , 7.959414487867278 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 6
# If Lambda* in [ 7.959414487867278 , 7.978609577146223 ]
# Condition to refute: Lambda* < -54.927
# Possible interval: [ -54.92701962041591 ,  inf ]
# J: 5
# If Lambda* in [ 7.978609577146223 , 7.994220670880381 ]
# Condition to refute: Lambda* < -23.474
# Possible interval: [ -23.474205021634845 ,  inf ]
# J: 4
# If Lambda* in [ 7.994220670880381 , 7.994355615739934 ]
# Condition to refute: Lambda* < -12.985
# Possible interval: [ -12.984729790796436 ,  inf ]
# J: 3
# If Lambda* in [ 7.994355615739934 , 7.998150417654415 ]
# Condition to refute: Lambda* < -7.74
# Possible interval: [ -7.7399584391623435 ,  inf ]
# J: 2
# If Lambda* in [ 7.998150417654415 , 7.999584265269988 ]
# Condition to refute: Lambda* < -4.592
# Possible interval: [ -4.592336667798992 ,  inf ]
# J: 1
# If Lambda* in [ 7.999584265269988 , 8.014663797254151 ]
# Condition to refute: Lambda* < -2.494
# Possible interval: [ -2.493683178954162 ,  inf ]
# J: 0
# If Lambda* in [ 8.014663797254151 , 8.036808727505473 ]
# Condition to refute: Lambda* < -0.992
# Possible interval: [ -0.9924907537815457 ,  inf ]
# J: -1
# If Lambda* in [ 7.959414487867278 , inf ]
# Condition to refute: Lambda* < 0.136
# Lambda is 1 and the possible lower bound is 0.13617168137933167
# Possible interval: [ 0.13617168137933167 ,  inf ]
# S0: [] | S1: [] | S: [0, 1, 2, 3, 4, 5, 6, 7]
# Pvl: 0.16402189755801447
#  [ -inf , inf ]
#
#
# [val : 8.1699, idx : 4, val : 8.1188, idx : 3, val : 8.01, idx : 2, val : 7.9606, idx : 6, val : 7.9594, idx : 5, val : 7.7391, idx : 1, val : 7.7009, idx : 7]
# omega: -1.0290647226686005
# J0: 6
# Lambda: 1
# First interval [ -inf , 7.70090419600038 ]
# J: 6
# If Lambda* in [ -inf , 7.70090419600038 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 6
# If Lambda* in [ -inf , 7.70090419600038 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ 7.70090419600038 , 7.739107444250948 ]
# Condition to refute: Lambda* < -46.929
# Possible interval: [ -46.928655317621796 ,  inf ]
# J: 4
# If Lambda* in [ 7.739107444250948 , 7.959365668968843 ]
# Condition to refute: Lambda* < -19.595
# Possible interval: [ -19.594773936685424 ,  inf ]
# J: 3
# If Lambda* in [ 7.959365668968843 , 7.960598709547995 ]
# Condition to refute: Lambda* < -10.41
# Possible interval: [ -10.410060734800668 ,  inf ]
# J: 2
# If Lambda* in [ 7.960598709547995 , 8.010018022401866 ]
# Condition to refute: Lambda* < -5.817
# Possible interval: [ -5.817395873713503 ,  inf ]
# J: 1
# If Lambda* in [ 8.010018022401866 , 8.11876409992145 ]
# Condition to refute: Lambda* < -3.052
# Possible interval: [ -3.051913094490429 ,  inf ]
# J: 0
# If Lambda* in [ 8.11876409992145 , 8.169866095199296 ]
# Condition to refute: Lambda* < -1.19
# Possible interval: [ -1.1901335620884492 ,  inf ]
# J: -1
# If Lambda* in [ 7.70090419600038 , inf ]
# Condition to refute: Lambda* < 0.147
# Lambda is 1 and the possible lower bound is 0.14700924609551436
# Possible interval: [ 0.14700924609551436 ,  inf ]
# S0: [] | S1: [0] | S: [1, 2, 3, 4, 5, 6, 7]
# Pvl: 1.153991306619842
#  [ -inf , inf ]
#
#
# [val : 8.0721, idx : 2, val : 8.0158, idx : 1, val : 8.0075, idx : 6, val : 8.0054, idx : 5, val : 8.0049, idx : 4, val : 7.9907, idx : 7, val : 7.9892, idx : 3]
# omega: -0.1841699569692139
# J0: 6
# Lambda: 1
# First interval [ -inf , 7.989162760583346 ]
# J: 6
# If Lambda* in [ -inf , 7.989162760583346 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 6
# If Lambda* in [ -inf , 7.989162760583346 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ 7.989162760583346 , 7.990678427881193 ]
# Condition to refute: Lambda* < -47.912
# Possible interval: [ -47.9122334567367 ,  inf ]
# J: 4
# If Lambda* in [ 7.990678427881193 , 8.004937537236545 ]
# Condition to refute: Lambda* < -19.961
# Possible interval: [ -19.960777514427754 ,  inf ]
# J: 3
# If Lambda* in [ 8.004937537236545 , 8.005414696517787 ]
# Condition to refute: Lambda* < -10.639
# Possible interval: [ -10.638872497206322 ,  inf ]
# J: 2
# If Lambda* in [ 8.005414696517787 , 8.007453078237203 ]
# Condition to refute: Lambda* < -5.978
# Possible interval: [ -5.977800698775294 ,  inf ]
# J: 1
# If Lambda* in [ 8.007453078237203 , 8.015836048960745 ]
# Condition to refute: Lambda* < -3.181
# Possible interval: [ -3.180749943372794 ,  inf ]
# J: 0
# If Lambda* in [ 8.015836048960745 , 8.07208362487244 ]
# Condition to refute: Lambda* < -1.315
# Possible interval: [ -1.314652277983871 ,  inf ]
# J: -1
# If Lambda* in [ 7.989162760583346 , inf ]
# Condition to refute: Lambda* < 0.026
# Lambda is 1 and the possible lower bound is 0.026309993852744844
# Possible interval: [ 0.026309993852744844 ,  inf ]
# S0: [0] | S1: [] | S: [1, 2, 3, 4, 5, 6, 7]
# Pvl: 0.4002545167933183
#  [ -inf , inf ]
#
#
# [val : 8.0252, idx : 4, val : 8.025, idx : 3, val : 8.0018, idx : 2, val : 7.9914, idx : 6, val : 7.9907, idx : 5, val : 7.9554, idx : 7]
# omega: -1.0296369503784106
# J0: 5
# Lambda: 1
# First interval [ -inf , 7.955402635452202 ]
# J: 5
# If Lambda* in [ -inf , 7.955402635452202 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ -inf , 7.955402635452202 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ 7.955402635452202 , 7.990719895632381 ]
# Condition to refute: Lambda* < -39.004
# Possible interval: [ -39.00447010392514 ,  inf ]
# J: 3
# If Lambda* in [ 7.990719895632381 , 7.991421075561078 ]
# Condition to refute: Lambda* < -15.507
# Possible interval: [ -15.506875104146378 ,  inf ]
# J: 2
# If Lambda* in [ 7.991421075561078 , 8.001773750904029 ]
# Condition to refute: Lambda* < -7.674
# Possible interval: [ -7.674109710910559 ,  inf ]
# J: 1
# If Lambda* in [ 8.001773750904029 , 8.024963889340953 ]
# Condition to refute: Lambda* < -3.755
# Possible interval: [ -3.755138845456912 ,  inf ]
# J: 0
# If Lambda* in [ 8.024963889340953 , 8.025228442865107 ]
# Condition to refute: Lambda* < -1.399
# Possible interval: [ -1.3991182984973392 ,  inf ]
# J: -1
# If Lambda* in [ 7.955402635452202 , inf ]
# Condition to refute: Lambda* < 0.172
# Lambda is 1 and the possible lower bound is 0.17160615839640178
# Possible interval: [ 0.17160615839640178 ,  inf ]
# S0: [] | S1: [0, 1] | S: [2, 3, 4, 5, 6, 7]
# Pvl: 2.1518515542769765
#  [ -inf , inf ]
#
#
# [val : 8.0972, idx : 7, val : 8.0234, idx : 2, val : 8.0058, idx : 3, val : 7.9928, idx : 4, val : 7.9728, idx : 6, val : 7.9533, idx : 5]
# omega: -0.5682982175693496
# J0: 5
# Lambda: 1
# First interval [ -inf , 7.953260475949797 ]
# J: 5
# If Lambda* in [ -inf , 7.953260475949797 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ -inf , 7.953260475949797 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ 7.953260475949797 , 7.972811120192702 ]
# Condition to refute: Lambda* < -39.524
# Possible interval: [ -39.5237122010608 ,  inf ]
# J: 3
# If Lambda* in [ 7.972811120192702 , 7.9928495962331425 ]
# Condition to refute: Lambda* < -15.775
# Possible interval: [ -15.77545054043405 ,  inf ]
# J: 2
# If Lambda* in [ 7.9928495962331425 , 8.00579703035389 ]
# Condition to refute: Lambda* < -7.853
# Possible interval: [ -7.852683828211653 ,  inf ]
# J: 1
# If Lambda* in [ 8.00579703035389 , 8.023363425208352 ]
# Condition to refute: Lambda* < -3.888
# Possible interval: [ -3.8880636135702673 ,  inf ]
# J: 0
# If Lambda* in [ 8.023363425208352 , 8.097189246642067 ]
# Condition to refute: Lambda* < -1.506
# Possible interval: [ -1.5057782058145435 ,  inf ]
# J: -1
# If Lambda* in [ 7.953260475949797 , inf ]
# Condition to refute: Lambda* < 0.095
# Lambda is 1 and the possible lower bound is 0.0947163695948916
# Possible interval: [ 0.0947163695948916 ,  inf ]
# S0: [1] | S1: [0] | S: [2, 3, 4, 5, 6, 7]
# Pvl: 1.2023849916227103
#  [ -inf , inf ]
#
#
# [val : 8.0704, idx : 2, val : 8.0089, idx : 6, val : 8.0068, idx : 5, val : 8.0062, idx : 4, val : 7.9906, idx : 7, val : 7.9889, idx : 3]
# omega: -0.16911812002187432
# J0: 5
# Lambda: 1
# First interval [ -inf , 7.98890258178373 ]
# J: 5
# If Lambda* in [ -inf , 7.98890258178373 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ -inf , 7.98890258178373 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ 7.98890258178373 , 7.990559504252204 ]
# Condition to refute: Lambda* < -39.914
# Possible interval: [ -39.91378047780765 ,  inf ]
# J: 3
# If Lambda* in [ 7.990559504252204 , 8.006204582883303 ]
# Condition to refute: Lambda* < -15.962
# Possible interval: [ -15.96161048677772 ,  inf ]
# J: 2
# If Lambda* in [ 8.006204582883303 , 8.006830106640805 ]
# Condition to refute: Lambda* < -7.972
# Possible interval: [ -7.972338796890713 ,  inf ]
# J: 1
# If Lambda* in [ 8.006830106640805 , 8.008861626785535 ]
# Condition to refute: Lambda* < -3.978
# Possible interval: [ -3.9775465710078333 ,  inf ]
# J: 0
# If Lambda* in [ 8.008861626785535 , 8.070442777267672 ]
# Condition to refute: Lambda* < -1.58
# Possible interval: [ -1.5802649314491597 ,  inf ]
# J: -1
# If Lambda* in [ 7.98890258178373 , inf ]
# Condition to refute: Lambda* < 0.028
# Lambda is 1 and the possible lower bound is 0.028186353336979053
# Possible interval: [ 0.028186353336979053 ,  inf ]
# S0: [0] | S1: [1] | S: [2, 3, 4, 5, 6, 7]
# Pvl: 1.3983257958700712
#  [ -inf , inf ]
#
#
# [val : 7.9939, idx : 7, val : 7.9933, idx : 3, val : 7.9932, idx : 4, val : 7.9875, idx : 2, val : 7.9175, idx : 6, val : 7.1617, idx : 5]
# omega: -0.13312869621808687
# J0: 5
# Lambda: 1
# First interval [ -inf , 7.161683534764984 ]
# J: 5
# If Lambda* in [ -inf , 7.161683534764984 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ -inf , 7.161683534764984 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ 7.161683534764984 , 7.917500752065365 ]
# Condition to refute: Lambda* < -39.752
# Possible interval: [ -39.7522360285836 ,  inf ]
# J: 3
# If Lambda* in [ 7.917500752065365 , 7.987450701125809 ]
# Condition to refute: Lambda* < -15.917
# Possible interval: [ -15.917367638259117 ,  inf ]
# J: 2
# If Lambda* in [ 7.987450701125809 , 7.993246769908646 ]
# Condition to refute: Lambda* < -7.949
# Possible interval: [ -7.949094858464142 ,  inf ]
# J: 1
# If Lambda* in [ 7.993246769908646 , 7.993262527521283 ]
# Condition to refute: Lambda* < -3.964
# Possible interval: [ -3.963509451370945 ,  inf ]
# J: 0
# If Lambda* in [ 7.993262527521283 , 7.993903974180583 ]
# Condition to refute: Lambda* < -1.572
# Possible interval: [ -1.5721550555924992 ,  inf ]
# J: -1
# If Lambda* in [ 7.161683534764984 , inf ]
# Condition to refute: Lambda* < 0.022
# Lambda is 1 and the possible lower bound is 0.02218811603634781
# Possible interval: [ 0.02218811603634781 ,  inf ]
# S0: [0, 1] | S1: [] | S: [2, 3, 4, 5, 6, 7]
# Pvl: 0.6136782965104659
#  [ -inf , inf ]
#
#
# [val : 8.0147, idx : 4, val : 8.0102, idx : 3, val : 7.9993, idx : 5, val : 7.9993, idx : 6, val : 7.9803, idx : 7]
# omega: -0.9553133864413361
# J0: 4
# Lambda: 1
# First interval [ -inf , 7.980337040990193 ]
# J: 4
# If Lambda* in [ -inf , 7.980337040990193 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 7.980337040990193 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 7.980337040990193 , 7.9993305213774235 ]
# Condition to refute: Lambda* < -31.068
# Possible interval: [ -31.068236170365434 ,  inf ]
# J: 2
# If Lambda* in [ 7.9993305213774235 , 7.999335327071577 ]
# Condition to refute: Lambda* < -11.534
# Possible interval: [ -11.534452824494007 ,  inf ]
# J: 1
# If Lambda* in [ 7.999335327071577 , 8.010195878905613 ]
# Condition to refute: Lambda* < -5.023
# Possible interval: [ -5.023190107305479 ,  inf ]
# J: 0
# If Lambda* in [ 8.010195878905613 , 8.01468782945216 ]
# Condition to refute: Lambda* < -1.765
# Possible interval: [ -1.7648436107527061 ,  inf ]
# J: -1
# If Lambda* in [ 7.980337040990193 , inf ]
# Condition to refute: Lambda* < 0.191
# Lambda is 1 and the possible lower bound is 0.19106267728826723
# Possible interval: [ 0.19106267728826723 ,  inf ]
# S0: [] | S1: [0, 1, 2] | S: [3, 4, 5, 6, 7]
# Pvl: 3.1380103252800264
#  [ -inf , inf ]
#
#
# [val : 8.1279, idx : 4, val : 8.0404, idx : 5, val : 8.0323, idx : 6, val : 7.9812, idx : 3, val : 7.9713, idx : 7]
# omega: -0.1408335096158968
# J0: 4
# Lambda: 1
# First interval [ -inf , 7.9713077763162055 ]
# J: 4
# If Lambda* in [ -inf , 7.9713077763162055 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 7.9713077763162055 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 7.9713077763162055 , 7.981202173923774 ]
# Condition to refute: Lambda* < -32.041
# Possible interval: [ -32.04105712069158 ,  inf ]
# J: 2
# If Lambda* in [ 7.981202173923774 , 8.032339819580049 ]
# Condition to refute: Lambda* < -12.03
# Possible interval: [ -12.029927473383903 ,  inf ]
# J: 1
# If Lambda* in [ 8.032339819580049 , 8.040408242101392 ]
# Condition to refute: Lambda* < -5.343
# Possible interval: [ -5.342505042395918 ,  inf ]
# J: 0
# If Lambda* in [ 8.040408242101392 , 8.12794039470226 ]
# Condition to refute: Lambda* < -1.997
# Possible interval: [ -1.996776721271591 ,  inf ]
# J: -1
# If Lambda* in [ 7.9713077763162055 , inf ]
# Condition to refute: Lambda* < 0.028
# Lambda is 1 and the possible lower bound is 0.02816670192317936
# Possible interval: [ 0.02816670192317936 ,  inf ]
# S0: [2] | S1: [0, 1] | S: [3, 4, 5, 6, 7]
# Pvl: 2.3500618810276404
#  [ -inf , inf ]
#
#
# [val : 8.116, idx : 7, val : 8.0135, idx : 3, val : 7.9778, idx : 4, val : 7.9618, idx : 6, val : 7.942, idx : 5]
# omega: -0.5133727071194514
# J0: 4
# Lambda: 1
# First interval [ -inf , 7.942005444685307 ]
# J: 4
# If Lambda* in [ -inf , 7.942005444685307 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 7.942005444685307 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 7.942005444685307 , 7.961845387987765 ]
# Condition to refute: Lambda* < -31.556
# Possible interval: [ -31.555835981612702 ,  inf ]
# J: 2
# If Lambda* in [ 7.961845387987765 , 7.977821750894343 ]
# Condition to refute: Lambda* < -11.797
# Possible interval: [ -11.796995296812469 ,  inf ]
# J: 1
# If Lambda* in [ 7.977821750894343 , 8.013494084478978 ]
# Condition to refute: Lambda* < -5.205
# Possible interval: [ -5.205389614243532 ,  inf ]
# J: 0
# If Lambda* in [ 8.013494084478978 , 8.116047465371068 ]
# Condition to refute: Lambda* < -1.901
# Possible interval: [ -1.9006686895629041 ,  inf ]
# J: -1
# If Lambda* in [ 7.942005444685307 , inf ]
# Condition to refute: Lambda* < 0.103
# Lambda is 1 and the possible lower bound is 0.10267454142389028
# Possible interval: [ 0.10267454142389028 ,  inf ]
# S0: [1] | S1: [0, 2] | S: [3, 4, 5, 6, 7]
# Pvl: 2.1952516397437947
#  [ -inf , inf ]
#
#
# [val : 8.4466, idx : 4, val : 8.0517, idx : 5, val : 8.0184, idx : 3, val : 8.0052, idx : 6, val : 8.0017, idx : 7]
# omega: -0.12581149357863453
# J0: 4
# Lambda: 1
# First interval [ -inf , 8.001732041189413 ]
# J: 4
# If Lambda* in [ -inf , 8.001732041189413 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 8.001732041189413 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 8.001732041189413 , 8.005151274213773 ]
# Condition to refute: Lambda* < -32.396
# Possible interval: [ -32.39599149257754 ,  inf ]
# J: 2
# If Lambda* in [ 8.005151274213773 , 8.018401221135463 ]
# Condition to refute: Lambda* < -12.195
# Possible interval: [ -12.19542010918188 ,  inf ]
# J: 1
# If Lambda* in [ 8.018401221135463 , 8.051661426403722 ]
# Condition to refute: Lambda* < -5.457
# Possible interval: [ -5.457479665742766 ,  inf ]
# J: 0
# If Lambda* in [ 8.051661426403722 , 8.44658906440321 ]
# Condition to refute: Lambda* < -2.08
# Possible interval: [ -2.0801943927061437 ,  inf ]
# J: -1
# If Lambda* in [ 8.001732041189413 , inf ]
# Condition to refute: Lambda* < 0.025
# Lambda is 1 and the possible lower bound is 0.025162298715726904
# Possible interval: [ 0.025162298715726904 ,  inf ]
# S0: [1, 2] | S1: [0] | S: [3, 4, 5, 6, 7]
# Pvl: 1.6732380476540079
#  [ -inf , inf ]
#
#
# [val : 8.03, idx : 6, val : 8.0273, idx : 5, val : 8.0264, idx : 4, val : 7.9966, idx : 7, val : 7.9945, idx : 3]
# omega: -0.16362403844399687
# J0: 4
# Lambda: 1
# First interval [ -inf , 7.994498632576885 ]
# J: 4
# If Lambda* in [ -inf , 7.994498632576885 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 7.994498632576885 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 7.994498632576885 , 7.996622690171051 ]
# Condition to refute: Lambda* < -31.917
# Possible interval: [ -31.916759347535297 ,  inf ]
# J: 2
# If Lambda* in [ 7.996622690171051 , 8.026445237912938 ]
# Condition to refute: Lambda* < -11.96
# Possible interval: [ -11.960068328682123 ,  inf ]
# J: 1
# If Lambda* in [ 8.026445237912938 , 8.027280576052576 ]
# Condition to refute: Lambda* < -5.298
# Possible interval: [ -5.2978971398171035 ,  inf ]
# J: 0
# If Lambda* in [ 8.027280576052576 , 8.03003488184273 ]
# Condition to refute: Lambda* < -1.967
# Possible interval: [ -1.966602710849683 ,  inf ]
# J: -1
# If Lambda* in [ 7.994498632576885 , inf ]
# Condition to refute: Lambda* < 0.033
# Lambda is 1 and the possible lower bound is 0.03272480768879937
# Possible interval: [ 0.03272480768879937 ,  inf ]
# S0: [0] | S1: [1, 2] | S: [3, 4, 5, 6, 7]
# Pvl: 2.397547032664563
#  [ -inf , inf ]
#
#
# [val : 8.0041, idx : 3, val : 7.9892, idx : 7, val : 7.9041, idx : 5, val : 7.8988, idx : 6, val : 7.8879, idx : 4]
# omega: -0.14183075935624778
# J0: 4
# Lambda: 1
# First interval [ -inf , 7.887852878713941 ]
# J: 4
# If Lambda* in [ -inf , 7.887852878713941 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 7.887852878713941 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 7.887852878713941 , 7.898829469420798 ]
# Condition to refute: Lambda* < -31.654
# Possible interval: [ -31.654380583761764 ,  inf ]
# J: 2
# If Lambda* in [ 7.898829469420798 , 7.904116310477294 ]
# Condition to refute: Lambda* < -11.878
# Possible interval: [ -11.87777555717048 ,  inf ]
# J: 1
# If Lambda* in [ 7.904116310477294 , 7.989181950279978 ]
# Condition to refute: Lambda* < -5.284
# Possible interval: [ -5.28381160128789 ,  inf ]
# J: 0
# If Lambda* in [ 7.989181950279978 , 8.004083612939938 ]
# Condition to refute: Lambda* < -1.966
# Possible interval: [ -1.9655632133959227 ,  inf ]
# J: -1
# If Lambda* in [ 7.887852878713941 , inf ]
# Condition to refute: Lambda* < 0.028
# Lambda is 1 and the possible lower bound is 0.028366151871249558
# Possible interval: [ 0.028366151871249558 ,  inf ]
# S0: [0, 2] | S1: [1] | S: [3, 4, 5, 6, 7]
# Pvl: 1.414818506229357
#  [ -inf , inf ]
#
#
# [val : 8.1121, idx : 3, val : 8.1022, idx : 7, val : 8.0377, idx : 6, val : 8.0129, idx : 4, val : 7.5946, idx : 5]
# omega: -0.12612246723400133
# J0: 4
# Lambda: 1
# First interval [ -inf , 7.5946239491119005 ]
# J: 4
# If Lambda* in [ -inf , 7.5946239491119005 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 7.5946239491119005 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 7.5946239491119005 , 8.012936199199538 ]
# Condition to refute: Lambda* < -32.139
# Possible interval: [ -32.138879500204425 ,  inf ]
# J: 2
# If Lambda* in [ 8.012936199199538 , 8.037726698047898 ]
# Condition to refute: Lambda* < -12.063
# Possible interval: [ -12.062971650502442 ,  inf ]
# J: 1
# If Lambda* in [ 8.037726698047898 , 8.102226582520267 ]
# Condition to refute: Lambda* < -5.363
# Possible interval: [ -5.362738867652329 ,  inf ]
# J: 0
# If Lambda* in [ 8.102226582520267 , 8.11211248767072 ]
# Condition to refute: Lambda* < -1.996
# Possible interval: [ -1.9964975051091796 ,  inf ]
# J: -1
# If Lambda* in [ 7.5946239491119005 , inf ]
# Condition to refute: Lambda* < 0.025
# Lambda is 1 and the possible lower bound is 0.025224493446800268
# Possible interval: [ 0.025224493446800268 ,  inf ]
# S0: [0, 1] | S1: [2] | S: [3, 4, 5, 6, 7]
# Pvl: 1.612590976918129
#  [ -inf , inf ]
#
#
# [val : 7.894, idx : 7, val : 7.8723, idx : 3, val : 7.8396, idx : 5, val : 7.8323, idx : 6, val : 6.6616, idx : 4]
# omega: -0.1210641523681204
# J0: 4
# Lambda: 1
# First interval [ -inf , 6.661579366773562 ]
# J: 4
# If Lambda* in [ -inf , 6.661579366773562 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 6.661579366773562 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 6.661579366773562 , 7.832275403232103 ]
# Condition to refute: Lambda* < -31.317
# Possible interval: [ -31.31710969636701 ,  inf ]
# J: 2
# If Lambda* in [ 7.832275403232103 , 7.8395730595073765 ]
# Condition to refute: Lambda* < -11.742
# Possible interval: [ -11.742417146567453 ,  inf ]
# J: 1
# If Lambda* in [ 7.8395730595073765 , 7.872308713880827 ]
# Condition to refute: Lambda* < -5.215
# Possible interval: [ -5.215087077875843 ,  inf ]
# J: 0
# If Lambda* in [ 7.872308713880827 , 7.894016672114823 ]
# Condition to refute: Lambda* < -1.943
# Possible interval: [ -1.9432381299366757 ,  inf ]
# J: -1
# If Lambda* in [ 6.661579366773562 , inf ]
# Condition to refute: Lambda* < 0.024
# Lambda is 1 and the possible lower bound is 0.024212830473624082
# Possible interval: [ 0.024212830473624082 ,  inf ]
# S0: [0, 1, 2] | S1: [] | S: [3, 4, 5, 6, 7]
# Pvl: 0.6760370505910244
#  [ -inf , inf ]
#
#
# [val : 8.037, idx : 4, val : 8.0158, idx : 5, val : 8.0133, idx : 6, val : 7.9154, idx : 7]
# omega: -0.6502197543009736
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.915400731517508 ]
# J: 3
# If Lambda* in [ -inf , 7.915400731517508 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.915400731517508 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.915400731517508 , 8.01329099248278 ]
# Condition to refute: Lambda* < -23.416
# Possible interval: [ -23.415811363024375 ,  inf ]
# J: 1
# If Lambda* in [ 8.01329099248278 , 8.015767027236542 ]
# Condition to refute: Lambda* < -7.701
# Possible interval: [ -7.701260185270797 ,  inf ]
# J: 0
# If Lambda* in [ 8.015767027236542 , 8.036973097606026 ]
# Condition to refute: Lambda* < -2.462
# Possible interval: [ -2.4622511144350177 ,  inf ]
# J: -1
# If Lambda* in [ 7.915400731517508 , inf ]
# Condition to refute: Lambda* < 0.163
# Lambda is 1 and the possible lower bound is 0.1625549385752434
# Possible interval: [ 0.1625549385752434 ,  inf ]
# S0: [] | S1: [0, 1, 2, 3] | S: [4, 5, 6, 7]
# Pvl: 4.0920725699916405
#  [ -inf , inf ]
#
#
# [val : 8.0121, idx : 6, val : 8.0103, idx : 5, val : 8.008, idx : 7, val : 8.0063, idx : 4]
# omega: -0.2360161017420861
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.00632879895935 ]
# J: 3
# If Lambda* in [ -inf , 8.00632879895935 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.00632879895935 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.00632879895935 , 8.008022403909898 ]
# Condition to refute: Lambda* < -23.794
# Possible interval: [ -23.794399497084065 ,  inf ]
# J: 1
# If Lambda* in [ 8.008022403909898 , 8.010304515204014 ]
# Condition to refute: Lambda* < -7.893
# Possible interval: [ -7.893188546587083 ,  inf ]
# J: 0
# If Lambda* in [ 8.010304515204014 , 8.012088679712237 ]
# Condition to refute: Lambda* < -2.592
# Possible interval: [ -2.592024192656717 ,  inf ]
# J: -1
# If Lambda* in [ 8.00632879895935 , inf ]
# Condition to refute: Lambda* < 0.059
# Lambda is 1 and the possible lower bound is 0.05900402543552152
# Possible interval: [ 0.05900402543552152 ,  inf ]
# S0: [3] | S1: [0, 1, 2] | S: [4, 5, 6, 7]
# Pvl: 3.4999881184303763
#  [ -inf , inf ]
#
#
# [val : 8.2077, idx : 6, val : 8.1896, idx : 5, val : 7.8374, idx : 7, val : 7.716, idx : 4]
# omega: -0.06702068258542049
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.716044188877413 ]
# J: 3
# If Lambda* in [ -inf , 7.716044188877413 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.716044188877413 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.716044188877413 , 7.837378467207223 ]
# Condition to refute: Lambda* < -24.168
# Possible interval: [ -24.167631591347224 ,  inf ]
# J: 1
# If Lambda* in [ 7.837378467207223 , 8.189575012908668 ]
# Condition to refute: Lambda* < -8.165
# Possible interval: [ -8.16512656207 ,  inf ]
# J: 0
# If Lambda* in [ 8.189575012908668 , 8.207698793816753 ]
# Condition to refute: Lambda* < -2.714
# Possible interval: [ -2.713559370410444 ,  inf ]
# J: -1
# If Lambda* in [ 7.716044188877413 , inf ]
# Condition to refute: Lambda* < 0.017
# Lambda is 1 and the possible lower bound is 0.016755170646355122
# Possible interval: [ 0.016755170646355122 ,  inf ]
# S0: [2] | S1: [0, 1, 3] | S: [4, 5, 6, 7]
# Pvl: 3.3409730312518446
#  [ -inf , inf ]
#
#
# [val : 8.5934, idx : 6, val : 8.5623, idx : 5, val : 8.3168, idx : 4, val : 8.3088, idx : 7]
# omega: -0.15758412738380656
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.308810888085816 ]
# J: 3
# If Lambda* in [ -inf , 8.308810888085816 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.308810888085816 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.308810888085816 , 8.316761517318838 ]
# Condition to refute: Lambda* < -25.315
# Possible interval: [ -25.31493511686182 ,  inf ]
# J: 1
# If Lambda* in [ 8.316761517318838 , 8.562335563417545 ]
# Condition to refute: Lambda* < -8.499
# Possible interval: [ -8.499086799771492 ,  inf ]
# J: 0
# If Lambda* in [ 8.562335563417545 , 8.593422163509246 ]
# Condition to refute: Lambda* < -2.812
# Possible interval: [ -2.811946012041813 ,  inf ]
# J: -1
# If Lambda* in [ 8.308810888085816 , inf ]
# Condition to refute: Lambda* < 0.039
# Lambda is 1 and the possible lower bound is 0.03939603184595164
# Possible interval: [ 0.03939603184595164 ,  inf ]
# S0: [2, 3] | S1: [0, 1] | S: [4, 5, 6, 7]
# Pvl: 3.522266747580277
#  [ -inf , inf ]
#
#
# [val : 8.1091, idx : 6, val : 8.1029, idx : 5, val : 8.0812, idx : 4, val : 7.7983, idx : 7]
# omega: -0.28646851458005074
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.798311110626344 ]
# J: 3
# If Lambda* in [ -inf , 7.798311110626344 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.798311110626344 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.798311110626344 , 8.081192312474972 ]
# Condition to refute: Lambda* < -24.007
# Possible interval: [ -24.006742825654538 ,  inf ]
# J: 1
# If Lambda* in [ 8.081192312474972 , 8.102875359466566 ]
# Condition to refute: Lambda* < -7.963
# Possible interval: [ -7.962775256589783 ,  inf ]
# J: 0
# If Lambda* in [ 8.102875359466566 , 8.10914366829305 ]
# Condition to refute: Lambda* < -2.608
# Possible interval: [ -2.607558384571 ,  inf ]
# J: -1
# If Lambda* in [ 7.798311110626344 , inf ]
# Condition to refute: Lambda* < 0.072
# Lambda is 1 and the possible lower bound is 0.07161712864501268
# Possible interval: [ 0.07161712864501268 ,  inf ]
# S0: [1] | S1: [0, 2, 3] | S: [4, 5, 6, 7]
# Pvl: 3.168118312932309
#  [ -inf , inf ]
#
#
# [val : 7.4636, idx : 4, val : 7.4214, idx : 5, val : 7.4079, idx : 6, val : 7.3986, idx : 7]
# omega: -0.17384475400855948
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.398632274699857 ]
# J: 3
# If Lambda* in [ -inf , 7.398632274699857 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.398632274699857 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.398632274699857 , 7.407852655664415 ]
# Condition to refute: Lambda* < -22.119
# Possible interval: [ -22.11903924484145 ,  inf ]
# J: 1
# If Lambda* in [ 7.407852655664415 , 7.421389544041412 ]
# Condition to refute: Lambda* < -7.356
# Possible interval: [ -7.355593294588518 ,  inf ]
# J: 0
# If Lambda* in [ 7.421389544041412 , 7.463641799144183 ]
# Condition to refute: Lambda* < -2.43
# Possible interval: [ -2.429932348378541 ,  inf ]
# J: -1
# If Lambda* in [ 7.398632274699857 , inf ]
# Condition to refute: Lambda* < 0.043
# Lambda is 1 and the possible lower bound is 0.04346118850213987
# Possible interval: [ 0.04346118850213987 ,  inf ]
# S0: [1, 3] | S1: [0, 2] | S: [4, 5, 6, 7]
# Pvl: 3.182406529960333
#  [ -inf , inf ]
#
#
# [val : 8.7853, idx : 4, val : 8.1117, idx : 5, val : 7.9878, idx : 6, val : 7.9177, idx : 7]
# omega: -0.05426391350169979
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.917689371108327 ]
# J: 3
# If Lambda* in [ -inf , 7.917689371108327 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.917689371108327 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.917689371108327 , 7.987822083494889 ]
# Condition to refute: Lambda* < -24.831
# Possible interval: [ -24.830533978023233 ,  inf ]
# J: 1
# If Lambda* in [ 7.987822083494889 , 8.111668425110308 ]
# Condition to refute: Lambda* < -8.421
# Possible interval: [ -8.421355947264173 ,  inf ]
# J: 0
# If Lambda* in [ 8.111668425110308 , 8.785307382919738 ]
# Condition to refute: Lambda* < -2.91
# Possible interval: [ -2.9103478231393463 ,  inf ]
# J: -1
# If Lambda* in [ 7.917689371108327 , inf ]
# Condition to refute: Lambda* < 0.014
# Lambda is 1 and the possible lower bound is 0.013565978375424947
# Possible interval: [ 0.013565978375424947 ,  inf ]
# S0: [1, 2] | S1: [0, 3] | S: [4, 5, 6, 7]
# Pvl: 2.6643560878983026
#  [ -inf , inf ]
#
#
# [val : 7.9965, idx : 4, val : 7.9951, idx : 5, val : 7.9945, idx : 6, val : 7.9928, idx : 7]
# omega: -0.1473372566932838
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.992760008324673 ]
# J: 3
# If Lambda* in [ -inf , 7.992760008324673 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.992760008324673 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.992760008324673 , 7.994507442259291 ]
# Condition to refute: Lambda* < -23.839
# Possible interval: [ -23.838797303552436 ,  inf ]
# J: 1
# If Lambda* in [ 7.994507442259291 , 7.995112109049618 ]
# Condition to refute: Lambda* < -7.922
# Possible interval: [ -7.9221449306465725 ,  inf ]
# J: 0
# If Lambda* in [ 7.995112109049618 , 7.996515008936811 ]
# Condition to refute: Lambda* < -2.616
# Possible interval: [ -2.6163925840811757 ,  inf ]
# J: -1
# If Lambda* in [ 7.992760008324673 , inf ]
# Condition to refute: Lambda* < 0.037
# Lambda is 1 and the possible lower bound is 0.03683431417332095
# Possible interval: [ 0.03683431417332095 ,  inf ]
# S0: [1, 2, 3] | S1: [0] | S: [4, 5, 6, 7]
# Pvl: 2.8047933702480137
#  [ -inf , inf ]
#
#
# [val : 8.126, idx : 6, val : 8.1186, idx : 5, val : 8.0841, idx : 7, val : 8.0113, idx : 4]
# omega: -0.11137971060320595
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.01128939196758 ]
# J: 3
# If Lambda* in [ -inf , 8.01128939196758 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.01128939196758 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.01128939196758 , 8.084079558970103 ]
# Condition to refute: Lambda* < -24.217
# Possible interval: [ -24.217348469744632 ,  inf ]
# J: 1
# If Lambda* in [ 8.084079558970103 , 8.11864481964637 ]
# Condition to refute: Lambda* < -8.067
# Possible interval: [ -8.066634455387264 ,  inf ]
# J: 0
# If Lambda* in [ 8.11864481964637 , 8.126003801731363 ]
# Condition to refute: Lambda* < -2.672
# Possible interval: [ -2.6715413637093857 ,  inf ]
# J: -1
# If Lambda* in [ 8.01128939196758 , inf ]
# Condition to refute: Lambda* < 0.028
# Lambda is 1 and the possible lower bound is 0.027844927650801488
# Possible interval: [ 0.027844927650801488 ,  inf ]
# S0: [0] | S1: [1, 2, 3] | S: [4, 5, 6, 7]
# Pvl: 3.3912162212914927
#  [ -inf , inf ]
#
#
# [val : 8.266, idx : 6, val : 8.2129, idx : 5, val : 8.1976, idx : 4, val : 8.1394, idx : 7]
# omega: -0.18491193385510307
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.139387727320724 ]
# J: 3
# If Lambda* in [ -inf , 8.139387727320724 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.139387727320724 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.139387727320724 , 8.197596975658072 ]
# Condition to refute: Lambda* < -24.492
# Possible interval: [ -24.491551657748012 ,  inf ]
# J: 1
# If Lambda* in [ 8.197596975658072 , 8.21285305772892 ]
# Condition to refute: Lambda* < -8.147
# Possible interval: [ -8.14697734104497 ,  inf ]
# J: 0
# If Lambda* in [ 8.21285305772892 , 8.266013558216123 ]
# Condition to refute: Lambda* < -2.694
# Possible interval: [ -2.693700541453673 ,  inf ]
# J: -1
# If Lambda* in [ 8.139387727320724 , inf ]
# Condition to refute: Lambda* < 0.046
# Lambda is 1 and the possible lower bound is 0.04622798346377577
# Possible interval: [ 0.04622798346377577 ,  inf ]
# S0: [0, 3] | S1: [1, 2] | S: [4, 5, 6, 7]
# Pvl: 2.7654668572665564
#  [ -inf , inf ]
#
#
# [val : 8.3598, idx : 6, val : 8.331, idx : 5, val : 8.1542, idx : 4, val : 8.0005, idx : 7]
# omega: -0.08354730356204954
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.00053249959003 ]
# J: 3
# If Lambda* in [ -inf , 8.00053249959003 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.00053249959003 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.00053249959003 , 8.154206207698778 ]
# Condition to refute: Lambda* < -24.761
# Possible interval: [ -24.76147820187643 ,  inf ]
# J: 1
# If Lambda* in [ 8.154206207698778 , 8.331035406639575 ]
# Condition to refute: Lambda* < -8.304
# Possible interval: [ -8.303635997088826 ,  inf ]
# J: 0
# If Lambda* in [ 8.331035406639575 , 8.359783891100125 ]
# Condition to refute: Lambda* < -2.759
# Possible interval: [ -2.758745529179359 ,  inf ]
# J: -1
# If Lambda* in [ 8.00053249959003 , inf ]
# Condition to refute: Lambda* < 0.021
# Lambda is 1 and the possible lower bound is 0.020886825890512384
# Possible interval: [ 0.020886825890512384 ,  inf ]
# S0: [0, 2] | S1: [1, 3] | S: [4, 5, 6, 7]
# Pvl: 2.4073482213933137
#  [ -inf , inf ]
#
#
# [val : 8.0097, idx : 6, val : 8.0095, idx : 5, val : 8.0079, idx : 7, val : 8.0073, idx : 4]
# omega: -0.18269881377130837
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.007313062750043 ]
# J: 3
# If Lambda* in [ -inf , 8.007313062750043 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.007313062750043 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.007313062750043 , 8.007942266628554 ]
# Condition to refute: Lambda* < -23.844
# Possible interval: [ -23.844437810080763 ,  inf ]
# J: 1
# If Lambda* in [ 8.007942266628554 , 8.009472899604342 ]
# Condition to refute: Lambda* < -7.918
# Possible interval: [ -7.918247771726105 ,  inf ]
# J: 0
# If Lambda* in [ 8.009472899604342 , 8.009721457619179 ]
# Condition to refute: Lambda* < -2.609
# Possible interval: [ -2.60900754794929 ,  inf ]
# J: -1
# If Lambda* in [ 8.007313062750043 , inf ]
# Condition to refute: Lambda* < 0.046
# Lambda is 1 and the possible lower bound is 0.04567470344282709
# Possible interval: [ 0.04567470344282709 ,  inf ]
# S0: [0, 2, 3] | S1: [1] | S: [4, 5, 6, 7]
# Pvl: 3.256291047705274
#  [ -inf , inf ]
#
#
# [val : 8.0352, idx : 4, val : 7.9939, idx : 7, val : 7.8045, idx : 6, val : 4.7384, idx : 5]
# omega: -0.04641938679808
# J0: 3
# Lambda: 1
# First interval [ -inf , 4.738437335793755 ]
# J: 3
# If Lambda* in [ -inf , 4.738437335793755 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 4.738437335793755 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 4.738437335793755 , 7.804540109670777 ]
# Condition to refute: Lambda* < -23.787
# Possible interval: [ -23.78722419587973 ,  inf ]
# J: 1
# If Lambda* in [ 7.804540109670777 , 7.99388152041054 ]
# Condition to refute: Lambda* < -7.991
# Possible interval: [ -7.991342043104477 ,  inf ]
# J: 0
# If Lambda* in [ 7.99388152041054 , 8.035221952596494 ]
# Condition to refute: Lambda* < -2.663
# Possible interval: [ -2.6629341885994715 ,  inf ]
# J: -1
# If Lambda* in [ 4.738437335793755 , inf ]
# Condition to refute: Lambda* < 0.012
# Lambda is 1 and the possible lower bound is 0.01160484669952
# Possible interval: [ 0.01160484669952 ,  inf ]
# S0: [0, 1] | S1: [2, 3] | S: [4, 5, 6, 7]
# Pvl: 2.6028239285353902
#  [ -inf , inf ]
#
#
# [val : 8.2166, idx : 6, val : 8.1893, idx : 5, val : 8.1375, idx : 4, val : 8.1238, idx : 7]
# omega: -0.2052053558407465
# J0: 3
# Lambda: 1
# First interval [ -inf , 8.123806345111895 ]
# J: 3
# If Lambda* in [ -inf , 8.123806345111895 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 8.123806345111895 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 8.123806345111895 , 8.137475229198898 ]
# Condition to refute: Lambda* < -24.338
# Possible interval: [ -24.338108944835298 ,  inf ]
# J: 1
# If Lambda* in [ 8.137475229198898 , 8.189252557018545 ]
# Condition to refute: Lambda* < -8.1
# Possible interval: [ -8.1003168578182 ,  inf ]
# J: 0
# If Lambda* in [ 8.189252557018545 , 8.216586514458601 ]
# Condition to refute: Lambda* < -2.67
# Possible interval: [ -2.6704603862059515 ,  inf ]
# J: -1
# If Lambda* in [ 8.123806345111895 , inf ]
# Condition to refute: Lambda* < 0.051
# Lambda is 1 and the possible lower bound is 0.05130133896018663
# Possible interval: [ 0.05130133896018663 ,  inf ]
# S0: [0, 1, 3] | S1: [2] | S: [4, 5, 6, 7]
# Pvl: 3.5224847511333626
#  [ -inf , inf ]
#
#
# [val : 8.1584, idx : 4, val : 7.9946, idx : 6, val : 7.9931, idx : 5, val : 7.9739, idx : 7]
# omega: -0.05402677274703471
# J0: 3
# Lambda: 1
# First interval [ -inf , 7.973877659248441 ]
# J: 3
# If Lambda* in [ -inf , 7.973877659248441 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 7.973877659248441 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 7.973877659248441 , 7.993059778062728 ]
# Condition to refute: Lambda* < -24.092
# Possible interval: [ -24.09210672331104 ,  inf ]
# J: 1
# If Lambda* in [ 7.993059778062728 , 7.994646165066088 ]
# Condition to refute: Lambda* < -8.05
# Possible interval: [ -8.049523472624156 ,  inf ]
# J: 0
# If Lambda* in [ 7.994646165066088 , 8.15842755292926 ]
# Condition to refute: Lambda* < -2.701
# Possible interval: [ -2.701466926727408 ,  inf ]
# J: -1
# If Lambda* in [ 7.973877659248441 , inf ]
# Condition to refute: Lambda* < 0.014
# Lambda is 1 and the possible lower bound is 0.013506693186758678
# Possible interval: [ 0.013506693186758678 ,  inf ]
# S0: [0, 1, 2] | S1: [3] | S: [4, 5, 6, 7]
# Pvl: 1.6675178251264984
#  [ -inf , inf ]
#
#
# [val : 6.5884, idx : 4, val : 6.4617, idx : 6, val : 6.3853, idx : 7, val : 6.3372, idx : 5]
# omega: -0.12046483010334441
# J0: 3
# Lambda: 1
# First interval [ -inf , 6.337249688237279 ]
# J: 3
# If Lambda* in [ -inf , 6.337249688237279 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 6.337249688237279 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 6.337249688237279 , 6.385333666591464 ]
# Condition to refute: Lambda* < -19.315
# Possible interval: [ -19.314965571958382 ,  inf ]
# J: 1
# If Lambda* in [ 6.385333666591464 , 6.461665342749612 ]
# Condition to refute: Lambda* < -6.465
# Possible interval: [ -6.464815952683459 ,  inf ]
# J: 0
# If Lambda* in [ 6.461665342749612 , 6.588431392720651 ]
# Condition to refute: Lambda* < -2.156
# Possible interval: [ -2.1559888542057686 ,  inf ]
# J: -1
# If Lambda* in [ 6.337249688237279 , inf ]
# Condition to refute: Lambda* < 0.03
# Lambda is 1 and the possible lower bound is 0.030116207525836103
# Possible interval: [ 0.030116207525836103 ,  inf ]
# S0: [0, 1, 2, 3] | S1: [] | S: [4, 5, 6, 7]
# Pvl: 3.4878068684309125
#  [ -inf , inf ]
#
#
# [val : 8.0486, idx : 6, val : 8.0456, idx : 5, val : 8.0078, idx : 7]
# omega: -0.3988100755113706
# J0: 2
# Lambda: 1
# First interval [ -inf , 8.007843686296923 ]
# J: 2
# If Lambda* in [ -inf , 8.007843686296923 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 8.007843686296923 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 8.007843686296923 , 8.045589363020511 ]
# Condition to refute: Lambda* < -15.695
# Possible interval: [ -15.695345706649853 ,  inf ]
# J: 0
# If Lambda* in [ 8.045589363020511 , 8.048566419140712 ]
# Condition to refute: Lambda* < -3.825
# Possible interval: [ -3.824878171814671 ,  inf ]
# J: -1
# If Lambda* in [ 8.007843686296923 , inf ]
# Condition to refute: Lambda* < 0.133
# Lambda is 1 and the possible lower bound is 0.13293669183712353
# Possible interval: [ 0.13293669183712353 ,  inf ]
# S0: [] | S1: [0, 1, 2, 3, 4] | S: [5, 6, 7]
# Pvl: 5.054831350760844
#  [ -inf , inf ]
#
#
# [val : 7.7688, idx : 7, val : 7.499, idx : 6, val : 7.4458, idx : 5]
# omega: -0.05364849659957294
# J0: 2
# Lambda: 1
# First interval [ -inf , 7.445803640863868 ]
# J: 2
# If Lambda* in [ -inf , 7.445803640863868 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 7.445803640863868 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# ...
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 7.816341896385071 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 7.816341896385071 , 7.863940155825411 ]
# Condition to refute: Lambda* < -7.818
# Possible interval: [ -7.818451451591889 ,  inf ]
# J: -1
# If Lambda* in [ 7.816341896385071 , inf ]
# Condition to refute: Lambda* < 0.023
# Lambda is 1 and the possible lower bound is 0.022744352116760957
# Possible interval: [ 0.022744352116760957 ,  inf ]
# S0: [0, 1, 2, 4] | S1: [3, 5] | S: [6, 7]
# Pvl: 2.6665918678354075
#  [ -inf , inf ]
#
#
# [val : 7.8819, idx : 7, val : 7.8547, idx : 6]
# omega: -0.04618284391432326
# J0: 1
# Lambda: 1
# First interval [ -inf , 7.854657887217575 ]
# J: 1
# If Lambda* in [ -inf , 7.854657887217575 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 7.854657887217575 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 7.854657887217575 , 7.881900550735743 ]
# Condition to refute: Lambda* < -7.836
# Possible interval: [ -7.83571770682142 ,  inf ]
# J: -1
# If Lambda* in [ 7.854657887217575 , inf ]
# Condition to refute: Lambda* < 0.023
# Lambda is 1 and the possible lower bound is 0.02309142195716163
# Possible interval: [ 0.02309142195716163 ,  inf ]
# S0: [0, 1, 2, 4, 5] | S1: [3] | S: [6, 7]
# Pvl: 1.779670252434315
#  [ -inf , inf ]
#
#
# [val : 7.9224, idx : 7]
# omega: -0.04408649771186646
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.92237380904055 ]
# J: 0
# If Lambda* in [ -inf , 7.92237380904055 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.92237380904055 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.92237380904055 , inf ]
# Condition to refute: Lambda* < 0.044
# Lambda is 1 and the possible lower bound is 0.04408649771186646
# Possible interval: [ 0.04408649771186646 ,  inf ]
# S0: [2, 4, 5, 6] | S1: [0, 1, 3] | S: [7]
# Pvl: 3.4651766640500425
#  [ -inf , inf ]
#
#
# [val : 7.9519, idx : 7]
# omega: -0.03746524207660418
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.951889628902187 ]
# J: 0
# If Lambda* in [ -inf , 7.951889628902187 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.951889628902187 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.951889628902187 , inf ]
# Condition to refute: Lambda* < 0.037
# Lambda is 1 and the possible lower bound is 0.03746524207660418
# Possible interval: [ 0.03746524207660418 ,  inf ]
# S0: [1, 2, 5, 6] | S1: [0, 3, 4] | S: [7]
# Pvl: 3.7201467114666222
#  [ -inf , inf ]
#
#
# [val : 7.8186, idx : 7]
# omega: -0.029995653450194837
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.818568308057028 ]
# J: 0
# If Lambda* in [ -inf , 7.818568308057028 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.818568308057028 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.818568308057028 , inf ]
# Condition to refute: Lambda* < 0.03
# Lambda is 1 and the possible lower bound is 0.029995653450194837
# Possible interval: [ 0.029995653450194837 ,  inf ]
# S0: [1, 2, 4, 5] | S1: [0, 3, 6] | S: [7]
# Pvl: 3.7483991817886655
#  [ -inf , inf ]
#
#
# [val : 8.2766, idx : 7]
# omega: -0.0310411094327101
# J0: 0
# Lambda: 1
# First interval [ -inf , 8.2766171126198 ]
# J: 0
# If Lambda* in [ -inf , 8.2766171126198 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 8.2766171126198 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 8.2766171126198 , inf ]
# Condition to refute: Lambda* < 0.031
# Lambda is 1 and the possible lower bound is 0.0310411094327101
# Possible interval: [ 0.0310411094327101 ,  inf ]
# S0: [1, 2, 4, 5, 6] | S1: [0, 3] | S: [7]
# Pvl: 2.878145818475418
#  [ -inf , inf ]
#
#
# [val : 8.0011, idx : 7]
# omega: -0.03944674367208734
# J0: 0
# Lambda: 1
# First interval [ -inf , 8.001089688159269 ]
# J: 0
# If Lambda* in [ -inf , 8.001089688159269 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 8.001089688159269 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 8.001089688159269 , inf ]
# Condition to refute: Lambda* < 0.039
# Lambda is 1 and the possible lower bound is 0.03944674367208734
# Possible interval: [ 0.03944674367208734 ,  inf ]
# S0: [0, 4, 5, 6] | S1: [1, 2, 3] | S: [7]
# Pvl: 3.6402693856551185
#  [ -inf , inf ]
#
#
# [val : 8.1163, idx : 7]
# omega: -0.03824372272239529
# J0: 0
# Lambda: 1
# First interval [ -inf , 8.11630488986097 ]
# J: 0
# If Lambda* in [ -inf , 8.11630488986097 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 8.11630488986097 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 8.11630488986097 , inf ]
# Condition to refute: Lambda* < 0.038
# Lambda is 1 and the possible lower bound is 0.03824372272239529
# Possible interval: [ 0.03824372272239529 ,  inf ]
# S0: [0, 2, 5, 6] | S1: [1, 3, 4] | S: [7]
# Pvl: 3.683754017573949
#  [ -inf , inf ]
#
#
# [val : 7.9779, idx : 7]
# omega: -0.039236007182553934
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.977853962570869 ]
# J: 0
# If Lambda* in [ -inf , 7.977853962570869 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.977853962570869 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.977853962570869 , inf ]
# Condition to refute: Lambda* < 0.039
# Lambda is 1 and the possible lower bound is 0.039236007182553934
# Possible interval: [ 0.039236007182553934 ,  inf ]
# S0: [0, 2, 4, 6] | S1: [1, 3, 5] | S: [7]
# Pvl: 3.6247927363538492
#  [ -inf , inf ]
#
#
# [val : 8.042, idx : 7]
# omega: -0.041087992861349676
# J0: 0
# Lambda: 1
# First interval [ -inf , 8.041962143792958 ]
# J: 0
# If Lambda* in [ -inf , 8.041962143792958 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 8.041962143792958 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 8.041962143792958 , inf ]
# Condition to refute: Lambda* < 0.041
# Lambda is 1 and the possible lower bound is 0.041087992861349676
# Possible interval: [ 0.041087992861349676 ,  inf ]
# S0: [0, 2, 4, 5] | S1: [1, 3, 6] | S: [7]
# Pvl: 3.6280381799221377
#  [ -inf , inf ]
#
#
# [val : 7.4987, idx : 7]
# omega: -0.03718649218247805
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.498709753959076 ]
# J: 0
# If Lambda* in [ -inf , 7.498709753959076 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.498709753959076 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.498709753959076 , inf ]
# Condition to refute: Lambda* < 0.037
# Lambda is 1 and the possible lower bound is 0.03718649218247805
# Possible interval: [ 0.03718649218247805 ,  inf ]
# S0: [0, 2, 4, 5, 6] | S1: [1, 3] | S: [7]
# Pvl: 2.7421592193181197
#  [ -inf , inf ]
#
#
# [val : 8.4476, idx : 7]
# omega: -0.03164472444714583
# J0: 0
# Lambda: 1
# First interval [ -inf , 8.447551718775781 ]
# J: 0
# If Lambda* in [ -inf , 8.447551718775781 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 8.447551718775781 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 8.447551718775781 , inf ]
# Condition to refute: Lambda* < 0.032
# Lambda is 1 and the possible lower bound is 0.03164472444714583
# Possible interval: [ 0.03164472444714583 ,  inf ]
# S0: [0, 1, 5, 6] | S1: [2, 3, 4] | S: [7]
# Pvl: 3.6044350841786974
#  [ -inf , inf ]
#
#
# [val : 7.9914, idx : 7]
# omega: -0.038131319270668484
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.991381882210824 ]
# J: 0
# If Lambda* in [ -inf , 7.991381882210824 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.991381882210824 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.991381882210824 , inf ]
# Condition to refute: Lambda* < 0.038
# Lambda is 1 and the possible lower bound is 0.038131319270668484
# Possible interval: [ 0.038131319270668484 ,  inf ]
# S0: [0, 1, 4, 5] | S1: [2, 3, 6] | S: [7]
# Pvl: 3.720814509448794
#  [ -inf , inf ]
#
#
# [val : 7.5396, idx : 7]
# omega: -0.03341453442651776
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.539582428882241 ]
# J: 0
# If Lambda* in [ -inf , 7.539582428882241 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.539582428882241 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.539582428882241 , inf ]
# Condition to refute: Lambda* < 0.033
# Lambda is 1 and the possible lower bound is 0.03341453442651776
# Possible interval: [ 0.03341453442651776 ,  inf ]
# S0: [0, 1, 4, 5, 6] | S1: [2, 3] | S: [7]
# Pvl: 2.823771542991997
#  [ -inf , inf ]
#
#
# [val : 7.8994, idx : 7]
# omega: -0.03488082350541788
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.899395494932282 ]
# J: 0
# If Lambda* in [ -inf , 7.899395494932282 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.899395494932282 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.899395494932282 , inf ]
# Condition to refute: Lambda* < 0.035
# Lambda is 1 and the possible lower bound is 0.03488082350541788
# Possible interval: [ 0.03488082350541788 ,  inf ]
# S0: [0, 1, 2, 5, 6] | S1: [3, 4] | S: [7]
# Pvl: 2.792153256976283
#  [ -inf , inf ]
#
#
# [val : 7.3789, idx : 7]
# omega: -0.03437749395267975
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.3788705712147795 ]
# J: 0
# If Lambda* in [ -inf , 7.3788705712147795 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.3788705712147795 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.3788705712147795 , inf ]
# Condition to refute: Lambda* < 0.034
# Lambda is 1 and the possible lower bound is 0.03437749395267975
# Possible interval: [ 0.03437749395267975 ,  inf ]
# S0: [0, 1, 2, 4] | S1: [3, 5, 6] | S: [7]
# Pvl: 3.6654020090304167
#  [ -inf , inf ]
#
#
# [val : 7.3802, idx : 7]
# omega: -0.03101433500756201
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.3802437351266015 ]
# J: 0
# If Lambda* in [ -inf , 7.3802437351266015 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.3802437351266015 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.3802437351266015 , inf ]
# Condition to refute: Lambda* < 0.031
# Lambda is 1 and the possible lower bound is 0.03101433500756201
# Possible interval: [ 0.03101433500756201 ,  inf ]
# S0: [0, 1, 2, 4, 6] | S1: [3, 5] | S: [7]
# Pvl: 2.853637175427658
#  [ -inf , inf ]
#
#
# [val : 7.5716, idx : 7]
# omega: -0.035789439463561834
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.571555458654444 ]
# J: 0
# If Lambda* in [ -inf , 7.571555458654444 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.571555458654444 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.571555458654444 , inf ]
# Condition to refute: Lambda* < 0.036
# Lambda is 1 and the possible lower bound is 0.035789439463561834
# Possible interval: [ 0.035789439463561834 ,  inf ]
# S0: [0, 1, 2, 4, 5] | S1: [3, 6] | S: [7]
# Pvl: 2.7786521814177423
#  [ -inf , inf ]
#
#
# [val : 7.3639, idx : 7]
# omega: -0.03469167176394805
# J0: 0
# Lambda: 1
# First interval [ -inf , 7.363941548918795 ]
# J: 0
# If Lambda* in [ -inf , 7.363941548918795 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 7.363941548918795 ]
# No condition, we have Omega + Sum > 0
# Lambda is 1 and the possible upper bound is inf
# Lambda is 1 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 7.363941548918795 , inf ]
# Condition to refute: Lambda* < 0.035
# Lambda is 1 and the possible lower bound is 0.03469167176394805
# Possible interval: [ 0.03469167176394805 ,  inf ]
# S0: [0, 1, 2, 4, 5, 6] | S1: [3] | S: [7]
# Pvl: 1.9214477766379239
#  [ -inf , inf ]
#
#
# []
# omega: 0.0009199701056132881
# J0: -1
# Lambda: 1
# Leaf Node
# S0: [0, 1, 2, 4, 5, 6] | S1: [3, 7] | S: []
# Pvl: 2.9164648947133163
#  [ -inf , inf ]

# %%
lower_bounds
# Out:
# [-inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf,
#  -inf]

# %%
highest_lower_bound = max(lower_bounds)
lowest_higher_bound = min(upper_bounds)
print("[", highest_lower_bound, ",", lowest_higher_bound, "]")
# Out:
# [ -inf , inf ]
