# %%
import numpy as np
import cvxpy as cp 
from queue import Queue
from copy import deepcopy
from time import sleep
from BnB_normal import BnBNormalAlgorythm
import pandas as pd

# %%
A = np.matrix([[1, 2, 3],[3, 4, 3],[2, 1, 0]])
B = np.matrix([[1, 2, 3],[3, 4, 3],[2, 1, 0]])
x = np.array([1,0,0.5])
y = np.matrix([3,4,5]).T
np.linalg.norm(x)
np.count_nonzero(x)
lambda_0 = 1
M0 = 10000
A @ B
# Out:
# matrix([[13, 13,  9],
#         [21, 25, 21],
#         [ 5,  8,  9]])

# %%
A @ x
# Out:
# matrix([[2.5, 4.5, 2. ]])

# %% [markdown]
# # We want to solve the following
#
# $$\min_{x \in \real^n} \frac{1}{2} ||y - A x||^2_2 + \lambda ||x||_0$$

# %%
def evaluation_main (y, A, x, alpha = lambda_0):
    value = 0.5 * np.linalg.norm( y - A @ x ) ** 2 + alpha * np.count_nonzero(x)    
    return value

# %%
evaluation_main(y, A, x)
# Out:
# 14.749999999999998

# %% [markdown]
# # We are going to create a BnB of the following
#
# $$\min_{x \in \real^n} \frac{1}{2} ||y - A x||^2_2 + \frac{\lambda}{M} ||x_{\bar{S}}||_1 + \lambda |S_1|$$

# %%
np.random.seed(421)
A = np.random.randint(-10, 10, (10, 10))
y = np.random.randint(-10, 10, (10, 1))
n = y.shape[0]
n
# Out:
# 10

# %%
lambda_0 = 1
M0 = 100


def evaluation_main (y, A, x, alpha = lambda_0):
    value = 0.5 * np.linalg.norm( y - A @ x ) ** 2 + alpha * np.count_nonzero(x)    
    return value


def check_bound(u, v):
    if v.pu <= u.pu:
        return v.pu, v
    else:
        return u.pu, u
    



def relax_problem (y, A, S0, S1, S, alpha = lambda_0, M = M0):
    n = y.shape[0]
    X = cp.Variable((n, 1))
    obj =  0.5 * cp.sum_squares(y - A @ X ) 
    obj +=  alpha / M * cp.norm(X[S], 1)
    obj += alpha * len(S1)

    
    if len(S0) == 0:
        constraint = [X <= M, -X <= M] 
    else:
        constraint = [X[S0] == 0, X <= M, -X <= M] 

    prob = cp.Problem(cp.Minimize( obj ), constraint)
    result = prob.solve(verbose = False, solver = cp.ECOS, abstol=1e-4, reltol=1e-4)
    
    #eliminate 0
    x_vector = X.value
    x_vector = np.where(abs(x_vector) < 1e-7, 0, x_vector )
    return result, x_vector



class Node:
    
    def __init__(self, n, S0, S1, S, A, y):
        self.level = n - len(S)
        self.A = A
        self.y = y
        self.S0 = S0
        self.S1 = S1
        self.S = S
        self.pvl = 0
        self.pu = None       #corresponds to obj func value in real problem with x
        self.x = None
        self.calculate_pvl()
        self.calculate_pu_x()
        
    
    def calculate_pvl (self) -> float:
        self.pvl, self.x = relax_problem(y, A, S0 = self.S0, S1 = self.S1, S = self.S)
        return self.pvl
        
    def calculate_pu_x (self) -> float:
        self.pu =  evaluation_main(y, A, self.x)
        return self.pu
        

    def __le__ (self, other) -> bool:
        return self.pvl <= other.pvl
    
    def __str__(self) -> str:
        text = f"S0: {self.S0} | S1: {self.S1} | S: {self.S}\nPvl: {self.pvl}\n\n"
        return text
    
    def __repr__(self) -> str:
        text = f"S0: {self.S0} | S1: {self.S1} | Pvl: {self.pvl}"
        return text

# %%
S = list(range(n))
S0 = []
S1 = []
u = Node(n, S0, S1, S, A, y)

# %%
S = list(range(n))
S0 = []
S1 = []

u1 = Node(n, S0, S1, S, A, y)
print(u1.x)
print(u1.calculate_pvl())
print(u1.calculate_pu_x())

S = deepcopy(u.S)
S1 = deepcopy(u.S1)
S0 = deepcopy(u.S0)

index = S.pop(0)
index2 = S.pop(0)

#None zero branch
S0.append(index)
S0.append(index2)

u2 = Node(n, S0, S1, S, A, y)

print(u1 >= u2)
print(u1.pu, u2.pu)
check_bound(u1, u2)
# Out:
# [[ 0.23170507]
#  [-0.43967887]
#  [-0.81020599]
#  [ 0.62298317]
#  [ 0.09508656]
#  [ 0.45371026]
#  [-0.08893891]
#  [ 0.82366556]
#  [-0.06056742]
#  [-1.4987601 ]]
# 0.051354165675013726
# 10.000101146445013
# False
# 10.000101146445013 22.80588833660041
# (10.000101146445013, S0: [] | S1: [] | Pvl: 0.051354165675013726)

# %% [markdown]
# ## We are going to create the order

# %%
S = list(range(n))
S0 = []
S1 = []

#crear queue
q = Queue()
u = Node(n, S0, S1, S, A, y)
q.put(u)

#optimum 
pv_opt = u.pu
node_opt = deepcopy(u)
print("first op:", pv_opt)




while not q.empty():
    
    u = q.get()
    print(f"u node: S0: {u.S0} | S1: {u.S1} | Pvl: {u.pvl}")
    
    #if the node is leaf
    if u.level == n  or len(u.S) == 0:
        continue
    
    S_v = deepcopy(u.S)
    S1_v = deepcopy(u.S1)
    S0_v = deepcopy(u.S0)
    
    index = S_v.pop(0)
    
    #None zero branch
    S1_v.append(index)
    
    v1 = Node(n, S0_v, S1_v, S_v, A, y)
    print("v1 pvl: ", v1.pvl)
    if not pv_opt <= v1.pvl:
        q.put(v1)
        print(v1.pu)             
        pv_opt, node_opt = check_bound(node_opt, v1)

        
    
    #Zero branch
    S_v = deepcopy(u.S)
    S1_v = deepcopy(u.S1)
    S0_v = deepcopy(u.S0)
    index = S_v.pop(0)
    S0_v.append(index)
    v0 = Node(n, S0_v, S1_v, S_v, A, y)
    print("V0 pvl:", v0.pvl)
    if not pv_opt <= v0.pvl:
        q.put(v0)
        print(v0.pu)             
        pv_opt, node_opt = check_bound(node_opt, v0)
    
    print("Queue:\t",list(q.queue), "\n")

    

print("Opt obj value:\t", pv_opt)
print("Optimum node:\n", node_opt )
# Out:
# first op: 10.000101146445013
# u node: S0: [] | S1: [] | Pvl: 0.051354165675013726
# v1 pvl:  1.0490305868541316
# 10.000063112047783
# V0 pvl: 0.25192521160595616
# 9.207988171831724
# Queue:	 [S0: [] | S1: [0] | Pvl: 1.0490305868541316, S0: [0] | S1: [] | Pvl: 0.25192521160595616]
#
# u node: S0: [] | S1: [0] | Pvl: 1.0490305868541316
# v1 pvl:  2.044623951208538
# 10.000047815949076
# V0 pvl: 3.137170806392232
# 11.099604311844722
# Queue:	 [S0: [0] | S1: [] | Pvl: 0.25192521160595616, S0: [] | S1: [0, 1] | Pvl: 2.044623951208538, S0: [1] | S1: [0] | Pvl: 3.137170806392232]
#
# u node: S0: [0] | S1: [] | Pvl: 0.25192521160595616
# v1 pvl:  1.2488451784407324
# 9.20798866013061
# V0 pvl: 14.854662245513893
# Queue:	 [S0: [] | S1: [0, 1] | Pvl: 2.044623951208538, S0: [1] | S1: [0] | Pvl: 3.137170806392232, S0: [0] | S1: [1] | Pvl: 1.2488451784407324]
#
# u node: S0: [] | S1: [0, 1] | Pvl: 2.044623951208538
# v1 pvl:  3.0365114934775246
# 10.000028746516655
# V0 pvl: 8.2354751769116
# 15.205751148022989
# Queue:	 [S0: [1] | S1: [0] | Pvl: 3.137170806392232, S0: [0] | S1: [1] | Pvl: 1.2488451784407324, S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246, S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116]
#
# u node: S0: [1] | S1: [0] | Pvl: 3.137170806392232
# v1 pvl:  4.131656120475425
# 11.099594675876057
# V0 pvl: 7.24403960969072
# 14.213992599904488
# Queue:	 [S0: [0] | S1: [1] | Pvl: 1.2488451784407324, S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246, S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116, S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072]
#
# u node: S0: [0] | S1: [1] | Pvl: 1.2488451784407324
# v1 pvl:  2.241620846789978
# 9.207979700484703
# V0 pvl: 8.955488283338461
# 15.930518324081504
# Queue:	 [S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246, S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116, S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461]
#
# u node: S0: [] | S1: [0, 1, 2] | Pvl: 3.0365114934775246
# v1 pvl:  4.030268578879637
# 10.000020520248443
# V0 pvl: 9.669539783003579
# Queue:	 [S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116, S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637]
#
# u node: S0: [2] | S1: [0, 1] | Pvl: 8.2354751769116
# v1 pvl:  9.23318340951582
# V0 pvl: 9.80003684801184
# Queue:	 [S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425, S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637]
#
# u node: S0: [1] | S1: [0, 2] | Pvl: 4.131656120475425
# v1 pvl:  5.128622963939962
# 11.09959347671162
# V0 pvl: 13.71458702828024
# Queue:	 [S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072, S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962]
#
# u node: S0: [1, 2] | S1: [0] | Pvl: 7.24403960969072
# v1 pvl:  8.241897529293093
# 14.213992783157078
# V0 pvl: 13.22536442509883
# Queue:	 [S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978, S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093]
#
# u node: S0: [0] | S1: [1, 2] | Pvl: 2.241620846789978
# v1 pvl:  3.236377307197531
# 9.207979055075711
# V0 pvl: 29.299768533737137
# Queue:	 [S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461, S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531]
#
# u node: S0: [0, 2] | S1: [1] | Pvl: 8.955488283338461
# v1 pvl:  9.95114535436729
# V0 pvl: 29.65973644982753
# Queue:	 [S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637, S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531]
#
# u node: S0: [] | S1: [0, 1, 2, 3] | Pvl: 4.030268578879637
# v1 pvl:  5.029297857008413
# 10.000012784381788
# V0 pvl: 4.123086788135314
# 9.094862909336262
# Queue:	 [S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962, S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531, S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314]
#
# u node: S0: [1] | S1: [0, 2, 3] | Pvl: 5.128622963939962
# v1 pvl:  6.125964298536562
# 11.099594927565242
# V0 pvl: 6.985196868735027
# 11.95466200998074
# Queue:	 [S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093, S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531, S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027]
#
# u node: S0: [1, 2] | S1: [0, 3] | Pvl: 8.241897529293093
# v1 pvl:  9.237224869833831
# V0 pvl: 15.997998250644692
# Queue:	 [S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531, S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027]
#
# u node: S0: [0] | S1: [1, 2, 3] | Pvl: 3.236377307197531
# v1 pvl:  4.236144510413908
# 9.207980544623002
# V0 pvl: 3.253980649144582
# 8.225475211630343
# Queue:	 [S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413, S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582]
#
# u node: S0: [] | S1: [0, 1, 2, 3, 4] | Pvl: 5.029297857008413
# v1 pvl:  6.02472902974682
# 10.000005029720413
# V0 pvl: 6.20798385244617
# 10.185071400331616
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314, S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617]
#
# u node: S0: [4] | S1: [0, 1, 2, 3] | Pvl: 4.123086788135314
# v1 pvl:  5.119624286574462
# 9.094858032388162
# V0 pvl: 6.671244799541298
# 10.651999896282918
# Queue:	 [S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562, S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298]
#
# u node: S0: [1] | S1: [0, 2, 3, 4] | Pvl: 6.125964298536562
# v1 pvl:  7.125438998969933
# 11.099588755049375
# V0 pvl: 6.153615958559417
# 10.128255208473062
# Queue:	 [S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027, S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417]
#
# u node: S0: [1, 4] | S1: [0, 2, 3] | Pvl: 6.985196868735027
# v1 pvl:  7.98156644099092
# 11.954657325907387
# V0 pvl: 9.790965156719869
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908, S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092]
#
# u node: S0: [0] | S1: [1, 2, 3, 4] | Pvl: 4.236144510413908
# v1 pvl:  5.232931718846851
# 9.20797409950276
# V0 pvl: 5.40554520770854
# 9.383697226801354
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582, S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854]
#
# u node: S0: [0, 4] | S1: [1, 2, 3] | Pvl: 3.253980649144582
# v1 pvl:  4.250497934666535
# 8.225470262791337
# V0 pvl: 5.833703033429291
# 9.814202568666614
# Queue:	 [S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682, S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291]
#
# u node: S0: [] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.02472902974682
# v1 pvl:  7.02384680448941
# 10.000010164396118
# V0 pvl: 6.207892050644231
# 9.181630652332993
# Queue:	 [S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617, S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231]
#
# u node: S0: [5] | S1: [0, 1, 2, 3, 4] | Pvl: 6.20798385244617
# v1 pvl:  7.205739481335416
# 10.185074343361357
# V0 pvl: 8.089842784920254
# 11.06313670124885
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462, S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254]
#
# u node: S0: [4] | S1: [0, 1, 2, 3, 5] | Pvl: 5.119624286574462
# v1 pvl:  6.11857492644226
# 9.094862391033383
# V0 pvl: 5.3979086493017325
# 8.371368004980898
# Queue:	 [S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298, S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325]
#
# u node: S0: [4, 5] | S1: [0, 1, 2, 3] | Pvl: 6.671244799541298
# v1 pvl:  7.667756706968763
# 10.652000977972795
# V0 pvl: 14.191219839065827
# Queue:	 [S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933, S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763]
#
# u node: S0: [1] | S1: [0, 2, 3, 4, 5] | Pvl: 7.125438998969933
# v1 pvl:  8.124114652130226
# 11.09959286592564
# V0 pvl: 7.5472940706716525
# 10.519261040671601
# Queue:	 [S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417, S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525]
#
# u node: S0: [1, 5] | S1: [0, 2, 3, 4] | Pvl: 6.153615958559417
# v1 pvl:  7.152056407958991
# 10.128257098811833
# V0 pvl: 7.2688503582354524
# 10.241521995942675
# Queue:	 [S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092, S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524]
#
# u node: S0: [1, 4] | S1: [0, 2, 3, 5] | Pvl: 7.98156644099092
# v1 pvl:  8.98091241453011
# V0 pvl: 8.090699717868512
# 11.062710743042018
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851, S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512]
#
# u node: S0: [0] | S1: [1, 2, 3, 4, 5] | Pvl: 5.232931718846851
# v1 pvl:  6.23183164669012
# 9.207978996336344
# V0 pvl: 5.533716474952211
# 8.506883132343493
# Queue:	 [S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854, S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211]
#
# u node: S0: [0, 5] | S1: [1, 2, 3, 4] | Pvl: 5.40554520770854
# v1 pvl:  6.403043279933726
# 9.383699295844487
# V0 pvl: 8.080347064548565
# 11.055145998915687
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535, S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5] | Pvl: 4.250497934666535
# v1 pvl:  5.249432565690158
# 8.225475081549263
# V0 pvl: 4.5374916247738
# 7.510653232727817
# Queue:	 [S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291, S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738]
#
# u node: S0: [0, 4, 5] | S1: [1, 2, 3] | Pvl: 5.833703033429291
# v1 pvl:  6.830181240887354
# 9.814204080337927
# V0 pvl: 13.533073270750393
# Queue:	 [S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941, S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354]
#
# u node: S0: [] | S1: [0, 1, 2, 3, 4, 5, 6] | Pvl: 7.02384680448941
# v1 pvl:  8.015589920490555
# V0 pvl: 13.141479962115891
# Queue:	 [S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231, S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354]
#
# u node: S0: [6] | S1: [0, 1, 2, 3, 4, 5] | Pvl: 6.207892050644231
# v1 pvl:  7.198418560043731
# 9.181623004461166
# V0 pvl: 36.265748322614236
# Queue:	 [S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416, S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731]
#
# u node: S0: [5] | S1: [0, 1, 2, 3, 4, 6] | Pvl: 7.205739481335416
# v1 pvl:  8.200492518281889
# V0 pvl: 15.112519842495688
# Queue:	 [S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254, S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731]
#
# u node: S0: [5, 6] | S1: [0, 1, 2, 3, 4] | Pvl: 8.089842784920254
# v1 pvl:  9.082569771302381
# V0 pvl: 48.73830442017784
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226, S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731]
#
# u node: S0: [4] | S1: [0, 1, 2, 3, 5, 6] | Pvl: 6.11857492644226
# v1 pvl:  7.110839171126247
# 9.094856161487211
# V0 pvl: 13.344039530785322
# Queue:	 [S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325, S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247]
#
# u node: S0: [4, 6] | S1: [0, 1, 2, 3, 5] | Pvl: 5.3979086493017325
# v1 pvl:  6.388854587994325
# 8.37136697195477
# V0 pvl: 45.54931471879404
# Queue:	 [S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763, S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [4, 5] | S1: [0, 1, 2, 3, 6] | Pvl: 7.667756706968763
# v1 pvl:  8.664103467746544
# V0 pvl: 15.315443540654618
# Queue:	 [S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226, S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1] | S1: [0, 2, 3, 4, 5, 6] | Pvl: 8.124114652130226
# v1 pvl:  9.117543833227847
# V0 pvl: 12.533855652448914
# Queue:	 [S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525, S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 6] | S1: [0, 2, 3, 4, 5] | Pvl: 7.5472940706716525
# v1 pvl:  8.538960779513426
# V0 pvl: 36.14483312744454
# Queue:	 [S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991, S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 5] | S1: [0, 2, 3, 4, 6] | Pvl: 7.152056407958991
# v1 pvl:  8.1459332217066
# V0 pvl: 21.19477322483008
# Queue:	 [S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524, S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 5, 6] | S1: [0, 2, 3, 4] | Pvl: 7.2688503582354524
# v1 pvl:  8.261452986227535
# V0 pvl: 52.31124554234554
# Queue:	 [S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512, S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [1, 4, 6] | S1: [0, 2, 3, 5] | Pvl: 8.090699717868512
# v1 pvl:  9.081593410693525
# V0 pvl: 48.72171205993041
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012, S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325]
#
# u node: S0: [0] | S1: [1, 2, 3, 4, 5, 6] | Pvl: 6.23183164669012
# v1 pvl:  7.224210235093943
# 9.207972410946489
# V0 pvl: 12.543049012592643
# Queue:	 [S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211, S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943]
#
# u node: S0: [0, 6] | S1: [1, 2, 3, 4, 5] | Pvl: 5.533716474952211
# v1 pvl:  6.524666779033901
# 8.506881940313304
# V0 pvl: 39.30959457126145
# Queue:	 [S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726, S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901]
#
# u node: S0: [0, 5] | S1: [1, 2, 3, 4, 6] | Pvl: 6.403043279933726
# v1 pvl:  7.398152920316563
# 9.38369649003174
# V0 pvl: 14.830106514895554
# Queue:	 [S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565, S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563]
#
# u node: S0: [0, 5, 6] | S1: [1, 2, 3, 4] | Pvl: 8.080347064548565
# v1 pvl:  9.07337120841115
# V0 pvl: 48.22547827062198
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158, S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5, 6] | Pvl: 5.249432565690158
# v1 pvl:  6.241684018323019
# 8.225468663707241
# V0 pvl: 12.499918021654498
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738, S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5] | Pvl: 4.5374916247738
# v1 pvl:  5.528403585763665
# 7.510651993544113
# V0 pvl: 45.155896179727954
# Queue:	 [S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354, S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665]
#
# u node: S0: [0, 4, 5] | S1: [1, 2, 3, 6] | Pvl: 6.830181240887354
# v1 pvl:  7.826540292867032
# V0 pvl: 14.430525113728898
# Queue:	 [S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731, S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665]
#
# u node: S0: [6] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198418560043731
# v1 pvl:  8.19832322592508
# V0 pvl: 7.198598456023529
# 8.181937513990238
# Queue:	 [S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529]
#
# u node: S0: [4] | S1: [0, 1, 2, 3, 5, 6, 7] | Pvl: 7.110839171126247
# v1 pvl:  8.108477152813952
# V0 pvl: 7.824538191212013
# Queue:	 [S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325, S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529]
#
# u node: S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 6.388854587994325
# v1 pvl:  7.386497768126252
# 8.371367805450843
# V0 pvl: 7.099400724458189
# 8.082635275435507
# Queue:	 [S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943, S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0] | S1: [1, 2, 3, 4, 5, 6, 7] | Pvl: 7.224210235093943
# v1 pvl:  8.220798108455053
# V0 pvl: 11.0513399087742
# Queue:	 [S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901, S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0, 6] | S1: [1, 2, 3, 4, 5, 7] | Pvl: 6.524666779033901
# v1 pvl:  7.521313987166529
# V0 pvl: 10.234107079686929
# Queue:	 [S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0, 5] | S1: [1, 2, 3, 4, 6, 7] | Pvl: 7.398152920316563
# v1 pvl:  8.39372064688965
# V0 pvl: 16.516822753215735
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7] | Pvl: 6.241684018323019
# v1 pvl:  7.238427254227806
# 8.225468551564735
# V0 pvl: 12.608313342825229
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665, S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7] | Pvl: 5.528403585763665
# v1 pvl:  6.525122578319298
# 7.510652146141352
# V0 pvl: 11.9981491823604
# Queue:	 [S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529, S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [6, 8] | S1: [0, 1, 2, 3, 4, 5, 7] | Pvl: 7.198598456023529
# v1 pvl:  8.18193689170781
# V0 pvl: 104.97379730593653
# Queue:	 [S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252, S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [4, 6] | S1: [0, 1, 2, 3, 5, 7, 8] | Pvl: 7.386497768126252
# v1 pvl:  8.371366188736342
# V0 pvl: 42.18159158894162
# Queue:	 [S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189, S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [4, 6, 8] | S1: [0, 1, 2, 3, 5, 7] | Pvl: 7.099400724458189
# v1 pvl:  8.082634574206425
# V0 pvl: 106.53126235815321
# Queue:	 [S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806, S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [0, 4] | S1: [1, 2, 3, 5, 6, 7, 8] | Pvl: 7.238427254227806
# v1 pvl:  8.225465479325454
# V0 pvl: 21.95641677008117
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8] | Pvl: 6.525122578319298
# v1 pvl:  7.510651296502245
# 7.510651299161866
# V0 pvl: 67.37261071778417
# Queue:	 [S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | Pvl: 7.510651296502245]
#
# u node: S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | Pvl: 7.510651296502245
# Opt obj value:	 7.510651299161866
# Optimum node:
#  S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | S: []
# Pvl: 7.510651296502245

# %%
np.random.seed(420)
n = 15
A = np.random.randint(-10, 10, (n, n))
y = np.random.randint(-10, 10, (n, 1))

lambda_0 = 1
M0 = 100

# %%
node = node_opt
node
# Out:
# S0: [0, 4, 6] | S1: [1, 2, 3, 5, 7, 8, 9] | Pvl: 7.510651296502245

# %%
u = node.y -  node.A @ node.x
node.A[: , 1 ] @ u
# Out:
# array([4.60092871e-06])

# %%
for i in range(5, -1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#A = np.eye(3)
#y = np.array([[3], [4], [5]])

#print("Solution Node")
## remember to count node 0
#print(f"Nodes visited {num_nodes}/{2**(n) + 1}")
#print(node)
#
#print(node.x)

#highest_lower_bound = max(lower_bounds)
#lowest_higher_bound = min(upper_bounds)

#A = np.random.randint(-10, 10, (n, n))
#y = np.random.randint(-10, 10, (n, 1))

np.random.seed(42)
A = np.eye(6)
y = np.array([[1], [2], [3], [4], [5], [6]])
print("Critical lambda values:", 0.5 * y.T ** 2)
lambda_0 = 30
M0 = 100

solver = BnBNormalAlgorythm(y, A, lambda0=lambda_0, M=M0)
pv, node, num_nodes, nodes = solver.solve(verbose=False)

print("Getting lambda intervals")
lower_bounds, upper_bounds = ([], [])
for node in nodes:
    lower_bound, upper_bound = node.get_lambda_interval(verbose = False)
    lower_bounds.append(lower_bound)
    upper_bounds.append(upper_bound)
print("[", max(lower_bounds), ",", min(upper_bounds), "]")
# Out:
# [[ 0.5  2.   4.5  8.  12.5 18. ]]
# Initializing normal solver BnB
# .
# ........
#
#             ############################################################
#             	Solver finished in:	1.968566656112671 s
#             ############################################################
#
# Getting lambda intervals
# [ -inf , inf ]

# %%
solver = BnBNormalAlgorythm(y, A, lambda0=lambda_0, M=M0)
pv, node, num_nodes, nodes = solver.solve(verbose=False)

print("Getting lambda intervals")
lower_bounds, upper_bounds = ([], [])
for node in nodes:
    lower_bound, upper_bound = node.get_lambda_interval(verbose = True)
    lower_bounds.append(lower_bound)
    upper_bounds.append(upper_bound)
print("[", max(lower_bounds), ",", min(upper_bounds), "]")
# Out:
# Initializing normal solver BnB
# .
# ........
#
#             ############################################################
#             	Solver finished in:	1.7665719985961914 s
#             ############################################################
#
# Getting lambda intervals
# S0: [] | S1: [] | S: [0, 1, 2, 3, 4, 5]
# Pvl: 4.733
#
# [[3.06493136e-06]
#  [2.01188157e-01]
#  [1.20003943e+00]
#  [2.19919779e+00]
#  [3.19866539e+00]
#  [4.19842925e+00]]
# [[0.99999694]
#  [1.79881184]
#  [1.79996057]
#  [1.80080221]
#  [1.80133461]
#  [1.80157075]]
# [val : 180.1571, idx : 5, val : 180.1335, idx : 4, val : 180.0802, idx : 3, val : 179.9961, idx : 2, val : 179.8812, idx : 1, val : 99.9997, idx : 0]
# omega: -19.80788060392955
# J0: 5
# Lambda: 30
# First interval [ -inf , 99.99969350686419 ]
# J: 5
# If Lambda* in [ -inf , 99.99969350686419 ]
# 980.4398110612284
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 5
# If Lambda* in [ -inf , 99.99969350686419 ]
# 980.4398110612284
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ 99.99969350686419 , 179.88118429776273 ]
# 880.4401175543642
# Condition to refute: Lambda* < -880.44
# Possible interval: [ -880.4401175543642 ,  inf ]
# J: 3
# If Lambda* in [ 179.88118429776273 , 179.99605729815633 ]
# 700.5589332566014
# Condition to refute: Lambda* < -350.279
# Possible interval: [ -350.2794666283007 ,  inf ]
# J: 2
# If Lambda* in [ 179.99605729815633 , 180.0802207776466 ]
# 520.5628759584451
# Condition to refute: Lambda* < -173.521
# Possible interval: [ -173.52095865281504 ,  inf ]
# J: 1
# If Lambda* in [ 180.0802207776466 , 180.13346051394709 ]
# 340.4826551807986
# Condition to refute: Lambda* < -85.121
# Possible interval: [ -85.12066379519965 ,  inf ]
# J: 0
# If Lambda* in [ 180.13346051394709 , 180.15707527078106 ]
# 160.3491946668515
# Condition to refute: Lambda* < -32.07
# Possible interval: [ -32.0698389333703 ,  inf ]
# J: -1
# If Lambda* in [ 99.99969350686419 , inf ]
# -19.80788060392955
# Condition to refute: Lambda* < 3.301
# Lambda is 30 and the possible lower bound is 3.3013134339882586
# Possible interval: [ 3.3013134339882586 ,  inf ]
# S0: [] | S1: [] | S: [0, 1, 2, 3, 4, 5]
# Pvl: 4.733
#  [ -inf , inf ]
#
#
# S0: [] | S1: [0] | S: [1, 2, 3, 4, 5]
# Pvl: 34.65
#
# [[0.99915552]
#  [0.19994129]
#  [1.20000691]
#  [2.20075676]
#  [3.20125099]
#  [4.20147888]]
# [[8.44483611e-04]
#  [1.80005871e+00]
#  [1.79999309e+00]
#  [1.79924324e+00]
#  [1.79874901e+00]
#  [1.79852112e+00]]
# [val : 180.0059, idx : 1, val : 179.9993, idx : 2, val : 179.9243, idx : 3, val : 179.8749, idx : 4, val : 179.8521, idx : 5]
# omega: -19.710697903352184
# J0: 4
# Lambda: 30
# First interval [ -inf , 179.85211231405708 ]
# J: 4
# If Lambda* in [ -inf , 179.85211231405708 ]
# 879.9458195602776
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 179.85211231405708 ]
# 879.9458195602776
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 179.85211231405708 , 179.87490139382749 ]
# 700.0937072462206
# Condition to refute: Lambda* < -700.094
# Possible interval: [ -700.0937072462206 ,  inf ]
# J: 2
# If Lambda* in [ 179.87490139382749 , 179.92432386592355 ]
# 520.2188058523931
# Condition to refute: Lambda* < -260.109
# Possible interval: [ -260.10940292619654 ,  inf ]
# J: 1
# If Lambda* in [ 179.92432386592355 , 179.99930899040936 ]
# 340.2944819864695
# Condition to refute: Lambda* < -113.431
# Possible interval: [ -113.43149399548984 ,  inf ]
# J: 0
# If Lambda* in [ 179.99930899040936 , 180.00587089941234 ]
# 160.29517299606016
# Condition to refute: Lambda* < -40.074
# Possible interval: [ -40.07379324901504 ,  inf ]
# J: -1
# If Lambda* in [ 179.85211231405708 , inf ]
# -19.710697903352184
# Condition to refute: Lambda* < 3.942
# Lambda is 30 and the possible lower bound is 3.9421395806704367
# Possible interval: [ 3.9421395806704367 ,  inf ]
# S0: [] | S1: [0] | S: [1, 2, 3, 4, 5]
# Pvl: 34.65
#  [ -inf , inf ]
#
#
# S0: [0] | S1: [] | S: [1, 2, 3, 4, 5]
# Pvl: 4.733
#
# [[0.        ]
#  [0.19971399]
#  [1.19967277]
#  [2.20002723]
#  [3.20017253]
#  [4.20020726]]
# [[1.        ]
#  [1.80028601]
#  [1.80032723]
#  [1.79997277]
#  [1.79982747]
#  [1.79979274]]
# [val : 180.0327, idx : 2, val : 180.0286, idx : 1, val : 179.9973, idx : 3, val : 179.9827, idx : 4, val : 179.9793, idx : 5]
# omega: -19.798595942796393
# J0: 4
# Lambda: 30
# First interval [ -inf , 179.9792743934055 ]
# J: 4
# If Lambda* in [ -inf , 179.9792743934055 ]
# 880.2220254108438
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 4
# If Lambda* in [ -inf , 179.9792743934055 ]
# 880.2220254108438
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ 179.9792743934055 , 179.9827469720298 ]
# 700.2427510174383
# Condition to refute: Lambda* < -700.243
# Possible interval: [ -700.2427510174383 ,  inf ]
# J: 2
# If Lambda* in [ 179.9827469720298 , 179.9972768079979 ]
# 520.2600040454086
# Condition to refute: Lambda* < -260.13
# Possible interval: [ -260.1300020227043 ,  inf ]
# J: 1
# If Lambda* in [ 179.9972768079979 , 180.02860060650002 ]
# 340.2627272374106
# Condition to refute: Lambda* < -113.421
# Possible interval: [ -113.42090907913688 ,  inf ]
# J: 0
# If Lambda* in [ 180.02860060650002 , 180.032722573707 ]
# 160.2341266309106
# Condition to refute: Lambda* < -40.059
# Possible interval: [ -40.05853165772765 ,  inf ]
# J: -1
# If Lambda* in [ 179.9792743934055 , inf ]
# -19.798595942796393
# Condition to refute: Lambda* < 3.96
# Lambda is 30 and the possible lower bound is 3.9597191885592786
# Possible interval: [ 3.9597191885592786 ,  inf ]
# S0: [0] | S1: [] | S: [1, 2, 3, 4, 5]
# Pvl: 4.733
#  [ -inf , inf ]
#
#
# S0: [] | S1: [0, 1] | S: [2, 3, 4, 5]
# Pvl: 64.32
#
# [[1.0004273 ]
#  [2.00085427]
#  [1.20030691]
#  [2.1998138 ]
#  [3.19950102]
#  [4.19937358]]
# [[-4.27297784e-04]
#  [-8.54274367e-04]
#  [ 1.79969309e+00]
#  [ 1.80018620e+00]
#  [ 1.80049898e+00]
#  [ 1.80062642e+00]]
# [val : 180.0626, idx : 5, val : 180.0499, idx : 4, val : 180.0186, idx : 3, val : 179.9693, idx : 2]
# omega: -19.31216587085128
# J0: 3
# Lambda: 30
# First interval [ -inf , 179.9693089086284 ]
# J: 3
# If Lambda* in [ -inf , 179.9693089086284 ]
# 700.7883033944888
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 179.9693089086284 ]
# 700.7883033944888
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 179.9693089086284 , 180.01862008407846 ]
# 520.8189944858605
# Condition to refute: Lambda* < -520.819
# Possible interval: [ -520.8189944858605 ,  inf ]
# J: 1
# If Lambda* in [ 180.01862008407846 , 180.04989783704045 ]
# 340.800374401782
# Condition to refute: Lambda* < -170.4
# Possible interval: [ -170.400187200891 ,  inf ]
# J: 0
# If Lambda* in [ 180.04989783704045 , 180.06264243559283 ]
# 160.75047656474155
# Condition to refute: Lambda* < -53.583
# Possible interval: [ -53.583492188247185 ,  inf ]
# J: -1
# If Lambda* in [ 179.9693089086284 , inf ]
# -19.31216587085128
# Condition to refute: Lambda* < 4.828
# Lambda is 30 and the possible lower bound is 4.82804146771282
# Possible interval: [ 4.82804146771282 ,  inf ]
# S0: [] | S1: [0, 1] | S: [2, 3, 4, 5]
# Pvl: 64.32
#  [ -inf , inf ]
#
#
# S0: [1] | S1: [0] | S: [2, 3, 4, 5]
# Pvl: 34.653
#
# [[0.99815781]
#  [0.        ]
#  [1.19845697]
#  [2.19935404]
#  [3.19974852]
#  [4.20010646]]
# [[1.84219065e-03]
#  [2.00000000e+00]
#  [1.80154303e+00]
#  [1.80064596e+00]
#  [1.80025148e+00]
#  [1.79989354e+00]]
# [val : 180.1543, idx : 2, val : 180.0646, idx : 3, val : 180.0251, idx : 4, val : 179.9894, idx : 5]
# omega: -19.257045998951984
# J0: 3
# Lambda: 30
# First interval [ -inf , 179.98935427564538 ]
# J: 3
# If Lambda* in [ -inf , 179.98935427564538 ]
# 700.9763547783679
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 179.98935427564538 ]
# 700.9763547783679
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 179.98935427564538 , 180.02514777487977 ]
# 520.9870005027225
# Condition to refute: Lambda* < -520.987
# Possible interval: [ -520.9870005027225 ,  inf ]
# J: 1
# If Lambda* in [ 180.02514777487977 , 180.0645960416065 ]
# 340.9618527278427
# Condition to refute: Lambda* < -170.481
# Possible interval: [ -170.48092636392136 ,  inf ]
# J: 0
# If Lambda* in [ 180.0645960416065 , 180.15430268518818 ]
# 160.8972566862362
# Condition to refute: Lambda* < -53.632
# Possible interval: [ -53.632418895412066 ,  inf ]
# J: -1
# If Lambda* in [ 179.98935427564538 , inf ]
# -19.257045998951984
# Condition to refute: Lambda* < 4.814
# Lambda is 30 and the possible lower bound is 4.814261499737996
# Possible interval: [ 4.814261499737996 ,  inf ]
# S0: [1] | S1: [0] | S: [2, 3, 4, 5]
# Pvl: 34.653
#  [ -inf , inf ]
#
#
# S0: [0] | S1: [1] | S: [2, 3, 4, 5]
# Pvl: 34.403
#
# [[0.        ]
#  [2.00017211]
#  [1.20016275]
#  [2.19996012]
#  [3.19986861]
#  [4.19983465]]
# [[ 1.00000000e+00]
#  [-1.72108536e-04]
#  [ 1.79983725e+00]
#  [ 1.80003988e+00]
#  [ 1.80013139e+00]
#  [ 1.80016535e+00]]
# [val : 180.0165, idx : 5, val : 180.0131, idx : 4, val : 180.004, idx : 3, val : 179.9837, idx : 2]
# omega: -19.423139200846897
# J0: 3
# Lambda: 30
# First interval [ -inf , 179.98372520530904 ]
# J: 3
# If Lambda* in [ -inf , 179.98372520530904 ]
# 700.5942470287329
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 179.98372520530904 ]
# 700.5942470287329
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 179.98372520530904 , 180.0039877188684 ]
# 520.6105218234238
# Condition to refute: Lambda* < -520.611
# Possible interval: [ -520.6105218234238 ,  inf ]
# J: 1
# If Lambda* in [ 180.0039877188684 , 180.0131385193568 ]
# 340.6065341045554
# Condition to refute: Lambda* < -170.303
# Possible interval: [ -170.3032670522777 ,  inf ]
# J: 0
# If Lambda* in [ 180.0131385193568 , 180.0165347860455 ]
# 160.5933955851986
# Condition to refute: Lambda* < -53.531
# Possible interval: [ -53.53113186173287 ,  inf ]
# J: -1
# If Lambda* in [ 179.98372520530904 , inf ]
# -19.423139200846897
# Condition to refute: Lambda* < 4.856
# Lambda is 30 and the possible lower bound is 4.855784800211724
# Possible interval: [ 4.855784800211724 ,  inf ]
# S0: [0] | S1: [1] | S: [2, 3, 4, 5]
# Pvl: 34.403
#  [ -inf , inf ]
#
#
# S0: [0, 1] | S1: [] | S: [2, 3, 4, 5]
# Pvl: 4.737
#
# [[0.        ]
#  [0.        ]
#  [1.19907006]
#  [2.20002524]
#  [3.20032493]
#  [4.20049699]]
# [[1.        ]
#  [2.        ]
#  [1.80092994]
#  [1.79997476]
#  [1.79967507]
#  [1.79950301]]
# [val : 180.093, idx : 2, val : 179.9975, idx : 3, val : 179.9675, idx : 4, val : 179.9503, idx : 5]
# omega: -19.43778303997064
# J0: 3
# Lambda: 30
# First interval [ -inf , 179.9503007843434 ]
# J: 3
# If Lambda* in [ -inf , 179.9503007843434 ]
# 700.5704949468926
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 3
# If Lambda* in [ -inf , 179.9503007843434 ]
# 700.5704949468926
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ 179.9503007843434 , 179.9675069348758 ]
# 520.6201941625492
# Condition to refute: Lambda* < -520.62
# Possible interval: [ -520.6201941625492 ,  inf ]
# J: 1
# If Lambda* in [ 179.9675069348758 , 179.99747636685638 ]
# 340.65268722767337
# Condition to refute: Lambda* < -170.326
# Possible interval: [ -170.32634361383668 ,  inf ]
# J: 0
# If Lambda* in [ 179.99747636685638 , 180.0929939007877 ]
# 160.65521086081705
# Condition to refute: Lambda* < -53.552
# Possible interval: [ -53.55173695360568 ,  inf ]
# J: -1
# If Lambda* in [ 179.9503007843434 , inf ]
# -19.43778303997064
# Condition to refute: Lambda* < 4.859
# Lambda is 30 and the possible lower bound is 4.85944575999266
# Possible interval: [ 4.85944575999266 ,  inf ]
# S0: [0, 1] | S1: [] | S: [2, 3, 4, 5]
# Pvl: 4.737
#  [ -inf , inf ]
#
#
# S0: [] | S1: [0, 1, 2] | S: [3, 4, 5]
# Pvl: 93.69
#
# [[1.00000002]
#  [2.00000005]
#  [3.00000009]
#  [2.19998295]
#  [3.19997743]
#  [4.19997978]]
# [[-2.23217711e-08]
#  [-4.98977113e-08]
#  [-8.79607249e-08]
#  [ 1.80001705e+00]
#  [ 1.80002257e+00]
#  [ 1.80002022e+00]]
# [val : 180.0023, idx : 4, val : 180.002, idx : 5, val : 180.0017, idx : 3]
# omega: -17.280070542021555
# J0: 2
# Lambda: 30
# First interval [ -inf , 180.00170525169858 ]
# J: 2
# If Lambda* in [ -inf , 180.00170525169858 ]
# 522.7259135297342
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 180.00170525169858 ]
# 522.7259135297342
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 180.00170525169858 , 180.00202227630257 ]
# 342.7242082780356
# Condition to refute: Lambda* < -342.724
# Possible interval: [ -342.7242082780356 ,  inf ]
# J: 0
# If Lambda* in [ 180.00202227630257 , 180.00225654375456 ]
# 162.722186001733
# Condition to refute: Lambda* < -81.361
# Possible interval: [ -81.3610930008665 ,  inf ]
# J: -1
# If Lambda* in [ 180.00170525169858 , inf ]
# -17.280070542021555
# Condition to refute: Lambda* < 5.76
# Lambda is 30 and the possible lower bound is 5.760023514007185
# Possible interval: [ 5.760023514007185 ,  inf ]
# S0: [] | S1: [0, 1, 2] | S: [3, 4, 5]
# Pvl: 93.69
#  [ -inf , inf ]
#
#
# S0: [2] | S1: [0, 1] | S: [3, 4, 5]
# Pvl: 64.44
#
# [[0.99962994]
#  [1.99926015]
#  [0.        ]
#  [2.19947967]
#  [3.1998694 ]
#  [4.19996262]]
# [[3.70062679e-04]
#  [7.39848460e-04]
#  [3.00000000e+00]
#  [1.80052033e+00]
#  [1.80013060e+00]
#  [1.80003738e+00]]
# [val : 180.052, idx : 3, val : 180.0131, idx : 4, val : 180.0037, idx : 5]
# omega: -17.171338365746152
# J0: 2
# Lambda: 30
# First interval [ -inf , 180.0037384123411 ]
# J: 2
# If Lambda* in [ -inf , 180.0037384123411 ]
# 522.8974933836699
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 180.0037384123411 ]
# 522.8974933836699
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 180.0037384123411 , 180.01305983812074 ]
# 342.8937549713288
# Condition to refute: Lambda* < -342.894
# Possible interval: [ -342.8937549713288 ,  inf ]
# J: 0
# If Lambda* in [ 180.01305983812074 , 180.0520334989542 ]
# 162.88069513320804
# Condition to refute: Lambda* < -81.44
# Possible interval: [ -81.44034756660402 ,  inf ]
# J: -1
# If Lambda* in [ 180.0037384123411 , inf ]
# -17.171338365746152
# Condition to refute: Lambda* < 5.724
# Lambda is 30 and the possible lower bound is 5.723779455248717
# Possible interval: [ 5.723779455248717 ,  inf ]
# S0: [2] | S1: [0, 1] | S: [3, 4, 5]
# Pvl: 64.44
#  [ -inf , inf ]
#
#
# S0: [1] | S1: [0, 2] | S: [3, 4, 5]
# Pvl: 64.023
#
# [[1.00007842]
#  [0.        ]
#  [3.00023519]
#  [2.19971118]
#  [3.19949345]
#  [4.19947112]]
# [[-7.84221555e-05]
#  [ 2.00000000e+00]
#  [-2.35188738e-04]
#  [ 1.80028882e+00]
#  [ 1.80050655e+00]
#  [ 1.80052888e+00]]
# [val : 180.0529, idx : 5, val : 180.0507, idx : 4, val : 180.0289, idx : 3]
# omega: -17.249948252542477
# J0: 2
# Lambda: 30
# First interval [ -inf , 180.0288821300935 ]
# J: 2
# If Lambda* in [ -inf , 180.0288821300935 ]
# 522.8824769878579
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 180.0288821300935 ]
# 522.8824769878579
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 180.0288821300935 , 180.05065516806198 ]
# 342.85359485776445
# Condition to refute: Lambda* < -342.854
# Possible interval: [ -342.85359485776445 ,  inf ]
# J: 0
# If Lambda* in [ 180.05065516806198 , 180.05288794224495 ]
# 162.80293968970247
# Condition to refute: Lambda* < -81.401
# Possible interval: [ -81.40146984485123 ,  inf ]
# J: -1
# If Lambda* in [ 180.0288821300935 , inf ]
# -17.249948252542477
# Condition to refute: Lambda* < 5.75
# Lambda is 30 and the possible lower bound is 5.749982750847493
# Possible interval: [ 5.749982750847493 ,  inf ]
# S0: [1] | S1: [0, 2] | S: [3, 4, 5]
# Pvl: 64.023
#  [ -inf , inf ]
#
#
# S0: [1, 2] | S1: [0] | S: [3, 4, 5]
# Pvl: 34.773
#
# [[1.00012138]
#  [0.        ]
#  [0.        ]
#  [2.19989789]
#  [3.19991481]
#  [4.19992564]]
# [[-1.21381664e-04]
#  [ 2.00000000e+00]
#  [ 3.00000000e+00]
#  [ 1.80010211e+00]
#  [ 1.80008519e+00]
#  [ 1.80007436e+00]]
# [val : 180.0102, idx : 3, val : 180.0085, idx : 4, val : 180.0074, idx : 5]
# omega: -17.26807899403313
# J0: 2
# Lambda: 30
# First interval [ -inf , 180.00743636857584 ]
# J: 2
# If Lambda* in [ -inf , 180.00743636857584 ]
# 522.7580871581057
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 180.00743636857584 ]
# 522.7580871581057
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 180.00743636857584 , 180.00851880149784 ]
# 342.75065078952974
# Condition to refute: Lambda* < -342.751
# Possible interval: [ -342.75065078952974 ,  inf ]
# J: 0
# If Lambda* in [ 180.00851880149784 , 180.01021098206508 ]
# 162.74213198803196
# Condition to refute: Lambda* < -81.371
# Possible interval: [ -81.37106599401598 ,  inf ]
# J: -1
# If Lambda* in [ 180.00743636857584 , inf ]
# -17.26807899403313
# Condition to refute: Lambda* < 5.756
# Lambda is 30 and the possible lower bound is 5.756026331344376
# Possible interval: [ 5.756026331344376 ,  inf ]
# S0: [1, 2] | S1: [0] | S: [3, 4, 5]
# Pvl: 34.773
#  [ -inf , inf ]
#
#
# S0: [0] | S1: [1, 2] | S: [3, 4, 5]
# Pvl: 63.773
#
# [[0.        ]
#  [2.00000099]
#  [3.00000152]
#  [2.19952825]
#  [3.19976488]
#  [4.19984625]]
# [[ 1.00000000e+00]
#  [-9.86839696e-07]
#  [-1.51824167e-06]
#  [ 1.80047175e+00]
#  [ 1.80023512e+00]
#  [ 1.80015375e+00]]
# [val : 180.0472, idx : 3, val : 180.0235, idx : 4, val : 180.0154, idx : 5]
# omega: -17.280629529868637
# J0: 2
# Lambda: 30
# First interval [ -inf , 180.01537477893353 ]
# J: 2
# If Lambda* in [ -inf , 180.01537477893353 ]
# 522.8054324092236
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 180.01537477893353 ]
# 522.8054324092236
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 180.01537477893353 , 180.02351245446798 ]
# 342.7900576302901
# Condition to refute: Lambda* < -342.79
# Possible interval: [ -342.7900576302901 ,  inf ]
# J: 0
# If Lambda* in [ 180.02351245446798 , 180.04717470569074 ]
# 162.7665451758221
# Condition to refute: Lambda* < -81.383
# Possible interval: [ -81.38327258791105 ,  inf ]
# J: -1
# If Lambda* in [ 180.01537477893353 , inf ]
# -17.280629529868637
# Condition to refute: Lambda* < 5.76
# Lambda is 30 and the possible lower bound is 5.760209843289545
# Possible interval: [ 5.760209843289545 ,  inf ]
# S0: [0] | S1: [1, 2] | S: [3, 4, 5]
# Pvl: 63.773
#  [ -inf , inf ]
#
#
# S0: [0, 2] | S1: [1] | S: [3, 4, 5]
# Pvl: 34.523
#
# [[0.        ]
#  [2.00321012]
#  [0.        ]
#  [2.20155255]
#  [3.2003787 ]
#  [4.19998138]]
# [[ 1.        ]
#  [-0.00321012]
#  [ 3.        ]
#  [ 1.79844745]
#  [ 1.7996213 ]
#  [ 1.80001862]]
# [val : 180.0019, idx : 5, val : 179.9621, idx : 4, val : 179.8447, idx : 3]
# omega: -16.951448081281512
# J0: 2
# Lambda: 30
# First interval [ -inf , 179.8447447594108 ]
# J: 2
# If Lambda* in [ -inf , 179.8447447594108 ]
# 522.857289107362
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 179.8447447594108 ]
# 522.857289107362
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 179.8447447594108 , 179.96213015554807 ]
# 343.0125443479513
# Condition to refute: Lambda* < -343.013
# Possible interval: [ -343.0125443479513 ,  inf ]
# J: 0
# If Lambda* in [ 179.96213015554807 , 180.00186227368476 ]
# 163.05041419240325
# Condition to refute: Lambda* < -81.525
# Possible interval: [ -81.52520709620163 ,  inf ]
# J: -1
# If Lambda* in [ 179.8447447594108 , inf ]
# -16.951448081281512
# Condition to refute: Lambda* < 5.65
# Lambda is 30 and the possible lower bound is 5.650482693760504
# Possible interval: [ 5.650482693760504 ,  inf ]
# S0: [0, 2] | S1: [1] | S: [3, 4, 5]
# Pvl: 34.523
#  [ -inf , inf ]
#
#
# S0: [0, 1] | S1: [2] | S: [3, 4, 5]
# Pvl: 34.107
#
# [[0.        ]
#  [0.        ]
#  [3.00349271]
#  [2.201262  ]
#  [3.19795077]
#  [4.19653977]]
# [[ 1.        ]
#  [ 2.        ]
#  [-0.00349271]
#  [ 1.798738  ]
#  [ 1.80204923]
#  [ 1.80346023]]
# [val : 180.346, idx : 5, val : 180.2049, idx : 4, val : 179.8738, idx : 3]
# omega: -16.930889865838395
# J0: 2
# Lambda: 30
# First interval [ -inf , 179.87380034083836 ]
# J: 2
# If Lambda* in [ -inf , 179.87380034083836 ]
# 523.4938564421412
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 179.87380034083836 ]
# 523.4938564421412
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 179.87380034083836 , 180.20492337506232 ]
# 343.6200561013029
# Condition to refute: Lambda* < -343.62
# Possible interval: [ -343.6200561013029 ,  inf ]
# J: 0
# If Lambda* in [ 180.20492337506232 , 180.34602259207898 ]
# 163.41513272624059
# Condition to refute: Lambda* < -81.708
# Possible interval: [ -81.70756636312029 ,  inf ]
# J: -1
# If Lambda* in [ 179.87380034083836 , inf ]
# -16.930889865838395
# Condition to refute: Lambda* < 5.644
# Lambda is 30 and the possible lower bound is 5.643629955279465
# Possible interval: [ 5.643629955279465 ,  inf ]
# S0: [0, 1] | S1: [2] | S: [3, 4, 5]
# Pvl: 34.107
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2] | S1: [] | S: [3, 4, 5]
# Pvl: 4.857
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [2.19981186]
#  [3.19983699]
#  [4.19987575]]
# [[1.        ]
#  [2.        ]
#  [3.        ]
#  [1.80018814]
#  [1.80016301]
#  [1.80012425]]
# [val : 180.0188, idx : 3, val : 180.0163, idx : 4, val : 180.0124, idx : 5]
# omega: -17.28060158893028
# J0: 2
# Lambda: 30
# First interval [ -inf , 180.01242476561973 ]
# J: 2
# If Lambda* in [ -inf , 180.01242476561973 ]
# 522.7669381360511
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 2
# If Lambda* in [ -inf , 180.01242476561973 ]
# 522.7669381360511
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ 180.01242476561973 , 180.01630121241067 ]
# 342.7545133704313
# Condition to refute: Lambda* < -342.755
# Possible interval: [ -342.7545133704313 ,  inf ]
# J: 0
# If Lambda* in [ 180.01630121241067 , 180.0188137469509 ]
# 162.73821215802064
# Condition to refute: Lambda* < -81.369
# Possible interval: [ -81.36910607901032 ,  inf ]
# J: -1
# If Lambda* in [ 180.01242476561973 , inf ]
# -17.28060158893028
# Condition to refute: Lambda* < 5.76
# Lambda is 30 and the possible lower bound is 5.760200529643427
# Possible interval: [ 5.760200529643427 ,  inf ]
# S0: [0, 1, 2] | S1: [] | S: [3, 4, 5]
# Pvl: 4.857
#  [ -inf , inf ]
#
#
# S0: [3] | S1: [0, 1, 2] | S: [4, 5]
# Pvl: 94.093
#
# [[0.99998057]
#  [1.99996122]
#  [2.99994203]
#  [0.        ]
#  [3.19964181]
#  [4.19948057]]
# [[1.94271289e-05]
#  [3.87761337e-05]
#  [5.79695236e-05]
#  [4.00000000e+00]
#  [1.80035819e+00]
#  [1.80051943e+00]]
# [val : 180.0519, idx : 5, val : 180.0358, idx : 4]
# omega: -13.310401301451064
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.03581923387438 ]
# J: 1
# If Lambda* in [ -inf , 180.03581923387438 ]
# 346.77736069005596
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.03581923387438 ]
# 346.77736069005596
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.03581923387438 , 180.05194275763267 ]
# 166.7415414561816
# Condition to refute: Lambda* < -166.742
# Possible interval: [ -166.7415414561816 ,  inf ]
# J: -1
# If Lambda* in [ 180.03581923387438 , inf ]
# -13.310401301451064
# Condition to refute: Lambda* < 6.655
# Lambda is 30 and the possible lower bound is 6.655200650725532
# Possible interval: [ 6.655200650725532 ,  inf ]
# S0: [3] | S1: [0, 1, 2] | S: [4, 5]
# Pvl: 94.093
#  [ -inf , inf ]
#
#
# S0: [2] | S1: [0, 1, 3] | S: [4, 5]
# Pvl: 93.51
#
# [[0.99994839]
#  [1.99989687]
#  [0.        ]
#  [3.99979449]
#  [3.20020826]
#  [4.20015314]]
# [[5.16101404e-05]
#  [1.03126618e-04]
#  [3.00000000e+00]
#  [2.05507355e-04]
#  [1.79979174e+00]
#  [1.79984686e+00]]
# [val : 179.9847, idx : 5, val : 179.9792, idx : 4]
# omega: -13.2843962450386
# J0: 1
# Lambda: 30
# First interval [ -inf , 179.97917368947833 ]
# J: 1
# If Lambda* in [ -inf , 179.97917368947833 ]
# 346.6794630403282
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 179.97917368947833 ]
# 346.6794630403282
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 179.97917368947833 , 179.98468559588846 ]
# 166.70028935084986
# Condition to refute: Lambda* < -166.7
# Possible interval: [ -166.70028935084986 ,  inf ]
# J: -1
# If Lambda* in [ 179.97917368947833 , inf ]
# -13.2843962450386
# Condition to refute: Lambda* < 6.642
# Lambda is 30 and the possible lower bound is 6.6421981225193
# Possible interval: [ 6.6421981225193 ,  inf ]
# S0: [2] | S1: [0, 1, 3] | S: [4, 5]
# Pvl: 93.51
#  [ -inf , inf ]
#
#
# S0: [2, 3] | S1: [0, 1] | S: [4, 5]
# Pvl: 64.843
#
# [[1.00012596]
#  [2.00025185]
#  [0.        ]
#  [0.        ]
#  [3.19979399]
#  [4.19988836]]
# [[-1.25963105e-04]
#  [-2.51845412e-04]
#  [ 3.00000000e+00]
#  [ 4.00000000e+00]
#  [ 1.80020601e+00]
#  [ 1.80011164e+00]]
# [val : 180.0206, idx : 4, val : 180.0112, idx : 5]
# omega: -13.282145705073185
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.0111639795529 ]
# J: 1
# If Lambda* in [ -inf , 180.0111639795529 ]
# 346.7496189499807
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.0111639795529 ]
# 346.7496189499807
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.0111639795529 , 180.02060067550096 ]
# 166.73845497042777
# Condition to refute: Lambda* < -166.738
# Possible interval: [ -166.73845497042777 ,  inf ]
# J: -1
# If Lambda* in [ 180.0111639795529 , inf ]
# -13.282145705073185
# Condition to refute: Lambda* < 6.641
# Lambda is 30 and the possible lower bound is 6.641072852536593
# Possible interval: [ 6.641072852536593 ,  inf ]
# S0: [2, 3] | S1: [0, 1] | S: [4, 5]
# Pvl: 64.843
#  [ -inf , inf ]
#
#
# S0: [1] | S1: [0, 2, 3] | S: [4, 5]
# Pvl: 93.093
#
# [[1.00023691]
#  [0.        ]
#  [3.00070619]
#  [4.00093635]
#  [3.20004268]
#  [4.19739104]]
# [[-2.36907858e-04]
#  [ 2.00000000e+00]
#  [-7.06186766e-04]
#  [-9.36352948e-04]
#  [ 1.79995732e+00]
#  [ 1.80260896e+00]]
# [val : 180.2609, idx : 5, val : 179.9957, idx : 4]
# omega: -13.132147878981822
# J0: 1
# Lambda: 30
# First interval [ -inf , 179.99573158997126 ]
# J: 1
# If Lambda* in [ -inf , 179.99573158997126 ]
# 347.1244801269506
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 179.99573158997126 ]
# 347.1244801269506
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 179.99573158997126 , 180.2608964159611 ]
# 167.1287485369793
# Condition to refute: Lambda* < -167.129
# Possible interval: [ -167.1287485369793 ,  inf ]
# J: -1
# If Lambda* in [ 179.99573158997126 , inf ]
# -13.132147878981822
# Condition to refute: Lambda* < 6.566
# Lambda is 30 and the possible lower bound is 6.566073939490911
# Possible interval: [ 6.566073939490911 ,  inf ]
# S0: [1] | S1: [0, 2, 3] | S: [4, 5]
# Pvl: 93.093
#  [ -inf , inf ]
#
#
# S0: [1, 3] | S1: [0, 2] | S: [4, 5]
# Pvl: 64.427
#
# [[0.99999353]
#  [0.        ]
#  [2.99998146]
#  [0.        ]
#  [3.19963684]
#  [4.19923317]]
# [[6.46521455e-06]
#  [2.00000000e+00]
#  [1.85413869e-05]
#  [4.00000000e+00]
#  [1.80036316e+00]
#  [1.80076683e+00]]
# [val : 180.0767, idx : 5, val : 180.0363, idx : 4]
# omega: -13.319909514950709
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.03631553192875 ]
# J: 1
# If Lambda* in [ -inf , 180.03631553192875 ]
# 346.7930888738515
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.03631553192875 ]
# 346.7930888738515
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.03631553192875 , 180.07668285687348 ]
# 166.75677334192278
# Condition to refute: Lambda* < -166.757
# Possible interval: [ -166.75677334192278 ,  inf ]
# J: -1
# If Lambda* in [ 180.03631553192875 , inf ]
# -13.319909514950709
# Condition to refute: Lambda* < 6.66
# Lambda is 30 and the possible lower bound is 6.659954757475354
# Possible interval: [ 6.659954757475354 ,  inf ]
# S0: [1, 3] | S1: [0, 2] | S: [4, 5]
# Pvl: 64.427
#  [ -inf , inf ]
#
#
# S0: [1, 2] | S1: [0, 3] | S: [4, 5]
# Pvl: 63.843
#
# [[1.00000817]
#  [0.        ]
#  [0.        ]
#  [4.00003233]
#  [3.19985591]
#  [4.19992159]]
# [[-8.17298225e-06]
#  [ 2.00000000e+00]
#  [ 3.00000000e+00]
#  [-3.23258596e-05]
#  [ 1.80014409e+00]
#  [ 1.80007841e+00]]
# [val : 180.0144, idx : 4, val : 180.0078, idx : 5]
# omega: -13.316202528101321
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.00784130940266 ]
# J: 1
# If Lambda* in [ -inf , 180.00784130940266 ]
# 346.7060477318297
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.00784130940266 ]
# 346.7060477318297
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.00784130940266 , 180.01440895052835 ]
# 166.69820642242703
# Condition to refute: Lambda* < -166.698
# Possible interval: [ -166.69820642242703 ,  inf ]
# J: -1
# If Lambda* in [ 180.00784130940266 , inf ]
# -13.316202528101321
# Condition to refute: Lambda* < 6.658
# Lambda is 30 and the possible lower bound is 6.658101264050661
# Possible interval: [ 6.658101264050661 ,  inf ]
# S0: [1, 2] | S1: [0, 3] | S: [4, 5]
# Pvl: 63.843
#  [ -inf , inf ]
#
#
# S0: [1, 2, 3] | S1: [0] | S: [4, 5]
# Pvl: 35.177
#
# [[1.00225173]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [3.19912047]
#  [4.1998992 ]]
# [[-2.25172631e-03]
#  [ 2.00000000e+00]
#  [ 3.00000000e+00]
#  [ 4.00000000e+00]
#  [ 1.80087953e+00]
#  [ 1.80010080e+00]]
# [val : 180.088, idx : 4, val : 180.0101, idx : 5]
# omega: -13.094043042166838
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.01007964140703 ]
# J: 1
# If Lambda* in [ -inf , 180.01007964140703 ]
# 347.00398963108046
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.01007964140703 ]
# 347.00398963108046
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.01007964140703 , 180.08795303184027 ]
# 166.99390998967343
# Condition to refute: Lambda* < -166.994
# Possible interval: [ -166.99390998967343 ,  inf ]
# J: -1
# If Lambda* in [ 180.01007964140703 , inf ]
# -13.094043042166838
# Condition to refute: Lambda* < 6.547
# Lambda is 30 and the possible lower bound is 6.547021521083419
# Possible interval: [ 6.547021521083419 ,  inf ]
# S0: [1, 2, 3] | S1: [0] | S: [4, 5]
# Pvl: 35.177
#  [ -inf , inf ]
#
#
# S0: [0] | S1: [1, 2, 3] | S: [4, 5]
# Pvl: 92.843
#
# [[0.        ]
#  [1.99972585]
#  [2.99959004]
#  [3.99945573]
#  [3.19967048]
#  [4.19969767]]
# [[1.00000000e+00]
#  [2.74147856e-04]
#  [4.09964920e-04]
#  [5.44273037e-04]
#  [1.80032952e+00]
#  [1.80030233e+00]]
# [val : 180.033, idx : 4, val : 180.0302, idx : 5]
# omega: -13.202302883958204
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.03023279579287 ]
# J: 1
# If Lambda* in [ -inf , 180.03023279579287 ]
# 346.860882410069
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.03023279579287 ]
# 346.860882410069
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.03023279579287 , 180.03295249823435 ]
# 166.83064961427615
# Condition to refute: Lambda* < -166.831
# Possible interval: [ -166.83064961427615 ,  inf ]
# J: -1
# If Lambda* in [ 180.03023279579287 , inf ]
# -13.202302883958204
# Condition to refute: Lambda* < 6.601
# Lambda is 30 and the possible lower bound is 6.601151441979102
# Possible interval: [ 6.601151441979102 ,  inf ]
# S0: [0] | S1: [1, 2, 3] | S: [4, 5]
# Pvl: 92.843
#  [ -inf , inf ]
#
#
# S0: [0, 3] | S1: [1, 2] | S: [4, 5]
# Pvl: 64.177
#
# [[0.        ]
#  [2.00002375]
#  [3.00003549]
#  [0.        ]
#  [3.20073565]
#  [4.20053975]]
# [[ 1.00000000e+00]
#  [-2.37461658e-05]
#  [-3.54866202e-05]
#  [ 4.00000000e+00]
#  [ 1.79926435e+00]
#  [ 1.79946025e+00]]
# [val : 179.946, idx : 5, val : 179.9264, idx : 4]
# omega: -13.311596627488145
# J0: 1
# Lambda: 30
# First interval [ -inf , 179.92643450234235 ]
# J: 1
# If Lambda* in [ -inf , 179.92643450234235 ]
# 346.5608632743392
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 179.92643450234235 ]
# 346.5608632743392
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 179.92643450234235 , 179.946025399485 ]
# 166.63442877199685
# Condition to refute: Lambda* < -166.634
# Possible interval: [ -166.63442877199685 ,  inf ]
# J: -1
# If Lambda* in [ 179.92643450234235 , inf ]
# -13.311596627488145
# Condition to refute: Lambda* < 6.656
# Lambda is 30 and the possible lower bound is 6.655798313744072
# Possible interval: [ 6.655798313744072 ,  inf ]
# S0: [0, 3] | S1: [1, 2] | S: [4, 5]
# Pvl: 64.177
#  [ -inf , inf ]
#
#
# S0: [0, 2] | S1: [1, 3] | S: [4, 5]
# Pvl: 63.593
#
# [[0.        ]
#  [2.00000656]
#  [0.        ]
#  [4.00001295]
#  [3.19988073]
#  [4.19992207]]
# [[ 1.00000000e+00]
#  [-6.56085634e-06]
#  [ 3.00000000e+00]
#  [-1.29496207e-05]
#  [ 1.80011927e+00]
#  [ 1.80007793e+00]]
# [val : 180.0119, idx : 4, val : 180.0078, idx : 5]
# omega: -13.318338006805183
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.00779250252413 ]
# J: 1
# If Lambda* in [ -inf , 180.00779250252413 ]
# 346.70138129243804
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.00779250252413 ]
# 346.70138129243804
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.00779250252413 , 180.0119267967191 ]
# 166.69358878991392
# Condition to refute: Lambda* < -166.694
# Possible interval: [ -166.69358878991392 ,  inf ]
# J: -1
# If Lambda* in [ 180.00779250252413 , inf ]
# -13.318338006805183
# Condition to refute: Lambda* < 6.659
# Lambda is 30 and the possible lower bound is 6.659169003402591
# Possible interval: [ 6.659169003402591 ,  inf ]
# S0: [0, 2] | S1: [1, 3] | S: [4, 5]
# Pvl: 63.593
#  [ -inf , inf ]
#
#
# S0: [0, 2, 3] | S1: [1] | S: [4, 5]
# Pvl: 34.927
#
# [[0.        ]
#  [2.00038153]
#  [0.        ]
#  [0.        ]
#  [3.19980905]
#  [4.19991392]]
# [[ 1.00000000e+00]
#  [-3.81526011e-04]
#  [ 3.00000000e+00]
#  [ 4.00000000e+00]
#  [ 1.80019095e+00]
#  [ 1.80008608e+00]]
# [val : 180.0191, idx : 4, val : 180.0086, idx : 5]
# omega: -13.281558077937829
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.0086076693688 ]
# J: 1
# If Lambda* in [ -inf , 180.0086076693688 ]
# 346.7461450500516
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.0086076693688 ]
# 346.7461450500516
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.0086076693688 , 180.01909545862063 ]
# 166.7375373806828
# Condition to refute: Lambda* < -166.738
# Possible interval: [ -166.7375373806828 ,  inf ]
# J: -1
# If Lambda* in [ 180.0086076693688 , inf ]
# -13.281558077937829
# Condition to refute: Lambda* < 6.641
# Lambda is 30 and the possible lower bound is 6.6407790389689145
# Possible interval: [ 6.6407790389689145 ,  inf ]
# S0: [0, 2, 3] | S1: [1] | S: [4, 5]
# Pvl: 34.927
#  [ -inf , inf ]
#
#
# S0: [0, 1] | S1: [2, 3] | S: [4, 5]
# Pvl: 63.177
#
# [[0.        ]
#  [0.        ]
#  [3.00069544]
#  [4.0009214 ]
#  [3.19717276]
#  [4.19512223]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [-6.95440613e-04]
#  [-9.21403789e-04]
#  [ 1.80282724e+00]
#  [ 1.80487777e+00]]
# [val : 180.4878, idx : 5, val : 180.2827, idx : 4]
# omega: -13.168175298631207
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.28272434994582 ]
# J: 1
# If Lambda* in [ -inf , 180.28272434994582 ]
# 347.6023262832354
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.28272434994582 ]
# 347.6023262832354
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.28272434994582 , 180.4877772319208 ]
# 167.3196019332896
# Condition to refute: Lambda* < -167.32
# Possible interval: [ -167.3196019332896 ,  inf ]
# J: -1
# If Lambda* in [ 180.28272434994582 , inf ]
# -13.168175298631207
# Condition to refute: Lambda* < 6.584
# Lambda is 30 and the possible lower bound is 6.584087649315603
# Possible interval: [ 6.584087649315603 ,  inf ]
# S0: [0, 1] | S1: [2, 3] | S: [4, 5]
# Pvl: 63.177
#  [ -inf , inf ]
#
#
# S0: [0, 1, 3] | S1: [2] | S: [4, 5]
# Pvl: 34.51
#
# [[0.        ]
#  [0.        ]
#  [3.0000432 ]
#  [0.        ]
#  [3.19973935]
#  [4.19971468]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [-4.31995102e-05]
#  [ 4.00000000e+00]
#  [ 1.80026065e+00]
#  [ 1.80028532e+00]]
# [val : 180.0285, idx : 5, val : 180.0261, idx : 4]
# omega: -13.316599969139073
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.02606493100103 ]
# J: 1
# If Lambda* in [ -inf , 180.02606493100103 ]
# 346.7379966645746
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.02606493100103 ]
# 346.7379966645746
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.02606493100103 , 180.02853170271268 ]
# 166.7119317335736
# Condition to refute: Lambda* < -166.712
# Possible interval: [ -166.7119317335736 ,  inf ]
# J: -1
# If Lambda* in [ 180.02606493100103 , inf ]
# -13.316599969139073
# Condition to refute: Lambda* < 6.658
# Lambda is 30 and the possible lower bound is 6.6582999845695365
# Possible interval: [ 6.6582999845695365 ,  inf ]
# S0: [0, 1, 3] | S1: [2] | S: [4, 5]
# Pvl: 34.51
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2] | S1: [3] | S: [4, 5]
# Pvl: 33.927
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [3.99999145]
#  [3.199714  ]
#  [4.19980144]]
# [[1.00000000e+00]
#  [2.00000000e+00]
#  [3.00000000e+00]
#  [8.55146544e-06]
#  [1.80028600e+00]
#  [1.80019856e+00]]
# [val : 180.0286, idx : 4, val : 180.0199, idx : 5]
# omega: -13.320055888035293
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.01985621003644 ]
# J: 1
# If Lambda* in [ -inf , 180.01985621003644 ]
# 346.7284003914913
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.01985621003644 ]
# 346.7284003914913
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.01985621003644 , 180.02860006949012 ]
# 166.70854418145484
# Condition to refute: Lambda* < -166.709
# Possible interval: [ -166.70854418145484 ,  inf ]
# J: -1
# If Lambda* in [ 180.01985621003644 , inf ]
# -13.320055888035293
# Condition to refute: Lambda* < 6.66
# Lambda is 30 and the possible lower bound is 6.660027944017647
# Possible interval: [ 6.660027944017647 ,  inf ]
# S0: [0, 1, 2] | S1: [3] | S: [4, 5]
# Pvl: 33.927
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 3] | S1: [] | S: [4, 5]
# Pvl: 5.26
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [3.19960852]
#  [4.19995119]]
# [[1.        ]
#  [2.        ]
#  [3.        ]
#  [4.        ]
#  [1.80039148]
#  [1.80004881]]
# [val : 180.0391, idx : 4, val : 180.0049, idx : 5]
# omega: -13.320665060877337
# J0: 1
# Lambda: 30
# First interval [ -inf , 180.00488127329507 ]
# J: 1
# If Lambda* in [ -inf , 180.00488127329507 ]
# 346.72336378057093
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 1
# If Lambda* in [ -inf , 180.00488127329507 ]
# 346.72336378057093
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ 180.00488127329507 , 180.03914756815317 ]
# 166.71848250727584
# Condition to refute: Lambda* < -166.718
# Possible interval: [ -166.71848250727584 ,  inf ]
# J: -1
# If Lambda* in [ 180.00488127329507 , inf ]
# -13.320665060877337
# Condition to refute: Lambda* < 6.66
# Lambda is 30 and the possible lower bound is 6.6603325304386685
# Possible interval: [ 6.6603325304386685 ,  inf ]
# S0: [0, 1, 2, 3] | S1: [] | S: [4, 5]
# Pvl: 5.26
#  [ -inf , inf ]
#
#
# S0: [2, 3, 4] | S1: [0, 1] | S: [5]
# Pvl: 65.697
#
# [[0.99999427]
#  [1.99998854]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [4.19955996]]
# [[5.72959413e-06]
#  [1.14573317e-05]
#  [3.00000000e+00]
#  [4.00000000e+00]
#  [5.00000000e+00]
#  [1.80044004e+00]]
# [val : 180.044, idx : 5]
# omega: -7.559365860123477
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.04400426040368 ]
# J: 0
# If Lambda* in [ -inf , 180.04400426040368 ]
# 172.4846384002802
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.04400426040368 ]
# 172.4846384002802
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.04400426040368 , inf ]
# -7.559365860123477
# Condition to refute: Lambda* < 7.559
# Lambda is 30 and the possible lower bound is 7.559365860123477
# Possible interval: [ 7.559365860123477 ,  inf ]
# S0: [2, 3, 4] | S1: [0, 1] | S: [5]
# Pvl: 65.697
#  [ -inf , inf ]
#
#
# S0: [1, 3, 4] | S1: [0, 2] | S: [5]
# Pvl: 65.28
#
# [[0.99998784]
#  [0.        ]
#  [2.99996397]
#  [0.        ]
#  [0.        ]
#  [4.19995852]]
# [[1.21608461e-05]
#  [2.00000000e+00]
#  [3.60334100e-05]
#  [4.00000000e+00]
#  [5.00000000e+00]
#  [1.80004148e+00]]
# [val : 180.0041, idx : 5]
# omega: -7.555400378097579
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.00414774188204 ]
# J: 0
# If Lambda* in [ -inf , 180.00414774188204 ]
# 172.44874736378446
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.00414774188204 ]
# 172.44874736378446
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.00414774188204 , inf ]
# -7.555400378097579
# Condition to refute: Lambda* < 7.555
# Lambda is 30 and the possible lower bound is 7.555400378097579
# Possible interval: [ 7.555400378097579 ,  inf ]
# S0: [1, 3, 4] | S1: [0, 2] | S: [5]
# Pvl: 65.28
#  [ -inf , inf ]
#
#
# S0: [1, 2, 4] | S1: [0, 3] | S: [5]
# Pvl: 64.697
#
# [[0.99987893]
#  [0.        ]
#  [0.        ]
#  [3.99952246]
#  [0.        ]
#  [4.19664853]]
# [[1.21066711e-04]
#  [2.00000000e+00]
#  [3.00000000e+00]
#  [4.77544326e-04]
#  [5.00000000e+00]
#  [1.80335147e+00]]
# [val : 180.3351, idx : 5]
# omega: -7.510202184677356
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.33514664325088 ]
# J: 0
# If Lambda* in [ -inf , 180.33514664325088 ]
# 172.82494445857353
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.33514664325088 ]
# 172.82494445857353
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.33514664325088 , inf ]
# -7.510202184677356
# Condition to refute: Lambda* < 7.51
# Lambda is 30 and the possible lower bound is 7.510202184677356
# Possible interval: [ 7.510202184677356 ,  inf ]
# S0: [1, 2, 4] | S1: [0, 3] | S: [5]
# ...
# First interval [ -inf , 180.03137982961005 ]
# J: 0
# If Lambda* in [ -inf , 180.03137982961005 ]
# 172.4712231354616
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.03137982961005 ]
# 172.4712231354616
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.03137982961005 , inf ]
# -7.56015669414846
# Condition to refute: Lambda* < 7.56
# Lambda is 30 and the possible lower bound is 7.56015669414846
# Possible interval: [ 7.56015669414846 ,  inf ]
# S0: [1, 2, 3, 4] | S1: [0] | S: [5]
# Pvl: 36.03
#  [ -inf , inf ]
#
#
# S0: [0, 3, 4] | S1: [1, 2] | S: [5]
# Pvl: 65.03
#
# [[0.        ]
#  [1.99992552]
#  [2.99988852]
#  [0.        ]
#  [0.        ]
#  [4.19979244]]
# [[1.00000000e+00]
#  [7.44813978e-05]
#  [1.11482259e-04]
#  [4.00000000e+00]
#  [5.00000000e+00]
#  [1.80020756e+00]]
# [val : 180.0208, idx : 5]
# omega: -7.542385114997742
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.02075550843796 ]
# J: 0
# If Lambda* in [ -inf , 180.02075550843796 ]
# 172.47837039344023
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.02075550843796 ]
# 172.47837039344023
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.02075550843796 , inf ]
# -7.542385114997742
# Condition to refute: Lambda* < 7.542
# Lambda is 30 and the possible lower bound is 7.542385114997742
# Possible interval: [ 7.542385114997742 ,  inf ]
# S0: [0, 3, 4] | S1: [1, 2] | S: [5]
# Pvl: 65.03
#  [ -inf , inf ]
#
#
# S0: [0, 2, 4] | S1: [1, 3] | S: [5]
# Pvl: 64.447
#
# [[0.        ]
#  [1.99976504]
#  [0.        ]
#  [3.99953487]
#  [0.        ]
#  [4.19539232]]
# [[1.00000000e+00]
#  [2.34962827e-04]
#  [3.00000000e+00]
#  [4.65130056e-04]
#  [5.00000000e+00]
#  [1.80460768e+00]]
# [val : 180.4608, idx : 5]
# omega: -7.503358078926391
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.46076764958076 ]
# J: 0
# If Lambda* in [ -inf , 180.46076764958076 ]
# 172.95740957065436
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.46076764958076 ]
# 172.95740957065436
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.46076764958076 , inf ]
# -7.503358078926391
# Condition to refute: Lambda* < 7.503
# Lambda is 30 and the possible lower bound is 7.503358078926391
# Possible interval: [ 7.503358078926391 ,  inf ]
# S0: [0, 2, 4] | S1: [1, 3] | S: [5]
# Pvl: 64.447
#  [ -inf , inf ]
#
#
# S0: [0, 2, 3] | S1: [1, 4] | S: [5]
# Pvl: 63.697
#
# [[0.        ]
#  [1.99980572]
#  [0.        ]
#  [0.        ]
#  [4.99951094]
#  [4.19933749]]
# [[1.00000000e+00]
#  [1.94275683e-04]
#  [3.00000000e+00]
#  [4.00000000e+00]
#  [4.89064816e-04]
#  [1.80066251e+00]]
# [val : 180.0663, idx : 5]
# omega: -7.49608914425761
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.06625144257552 ]
# J: 0
# If Lambda* in [ -inf , 180.06625144257552 ]
# 172.5701622983179
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.06625144257552 ]
# 172.5701622983179
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.06625144257552 , inf ]
# -7.49608914425761
# Condition to refute: Lambda* < 7.496
# Lambda is 30 and the possible lower bound is 7.49608914425761
# Possible interval: [ 7.49608914425761 ,  inf ]
# S0: [0, 2, 3] | S1: [1, 4] | S: [5]
# Pvl: 63.697
#  [ -inf , inf ]
#
#
# S0: [0, 2, 3, 4] | S1: [1] | S: [5]
# Pvl: 35.78
#
# [[0.        ]
#  [1.99999072]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [4.19962756]]
# [[1.00000000e+00]
#  [9.27601812e-06]
#  [3.00000000e+00]
#  [4.00000000e+00]
#  [5.00000000e+00]
#  [1.80037244e+00]]
# [val : 180.0372, idx : 5]
# omega: -7.559984668930603
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.03724406266582 ]
# J: 0
# If Lambda* in [ -inf , 180.03724406266582 ]
# 172.4772593937352
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.03724406266582 ]
# 172.4772593937352
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.03724406266582 , inf ]
# -7.559984668930603
# Condition to refute: Lambda* < 7.56
# Lambda is 30 and the possible lower bound is 7.559984668930603
# Possible interval: [ 7.559984668930603 ,  inf ]
# S0: [0, 2, 3, 4] | S1: [1] | S: [5]
# Pvl: 35.78
#  [ -inf , inf ]
#
#
# S0: [0, 1, 4] | S1: [2, 3] | S: [5]
# Pvl: 64.03
#
# [[0.        ]
#  [0.        ]
#  [3.00022106]
#  [4.00029665]
#  [0.        ]
#  [4.20333508]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [-2.21061155e-04]
#  [-2.96654815e-04]
#  [ 5.00000000e+00]
#  [ 1.79666492e+00]]
# [val : 179.6665, idx : 5]
# omega: -7.498363138353916
# J0: 0
# Lambda: 30
# First interval [ -inf , 179.66649157536665 ]
# J: 0
# If Lambda* in [ -inf , 179.66649157536665 ]
# 172.16812843701274
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 179.66649157536665 ]
# 172.16812843701274
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 179.66649157536665 , inf ]
# -7.498363138353916
# Condition to refute: Lambda* < 7.498
# Lambda is 30 and the possible lower bound is 7.498363138353916
# Possible interval: [ 7.498363138353916 ,  inf ]
# S0: [0, 1, 4] | S1: [2, 3] | S: [5]
# Pvl: 64.03
#  [ -inf , inf ]
#
#
# S0: [0, 1, 3] | S1: [2, 4] | S: [5]
# Pvl: 63.28
#
# [[0.        ]
#  [0.        ]
#  [3.00000152]
#  [0.        ]
#  [5.00000252]
#  [4.19995323]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [-1.52434091e-06]
#  [ 4.00000000e+00]
#  [-2.52489401e-06]
#  [ 1.80004677e+00]]
# [val : 180.0047, idx : 5]
# omega: -7.559690128727828
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.00467716284075 ]
# J: 0
# If Lambda* in [ -inf , 180.00467716284075 ]
# 172.44498703411293
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.00467716284075 ]
# 172.44498703411293
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.00467716284075 , inf ]
# -7.559690128727828
# Condition to refute: Lambda* < 7.56
# Lambda is 30 and the possible lower bound is 7.559690128727828
# Possible interval: [ 7.559690128727828 ,  inf ]
# S0: [0, 1, 3] | S1: [2, 4] | S: [5]
# Pvl: 63.28
#  [ -inf , inf ]
#
#
# S0: [0, 1, 3, 4] | S1: [2] | S: [5]
# Pvl: 35.363
#
# [[0.        ]
#  [0.        ]
#  [3.00001654]
#  [0.        ]
#  [0.        ]
#  [4.19991024]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [-1.65380952e-05]
#  [ 4.00000000e+00]
#  [ 5.00000000e+00]
#  [ 1.80008976e+00]]
# [val : 180.009, idx : 5]
# omega: -7.558512003455002
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.00897648303126 ]
# J: 0
# If Lambda* in [ -inf , 180.00897648303126 ]
# 172.45046447957625
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.00897648303126 ]
# 172.45046447957625
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.00897648303126 , inf ]
# -7.558512003455002
# Condition to refute: Lambda* < 7.559
# Lambda is 30 and the possible lower bound is 7.558512003455002
# Possible interval: [ 7.558512003455002 ,  inf ]
# S0: [0, 1, 3, 4] | S1: [2] | S: [5]
# Pvl: 35.363
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2] | S1: [3, 4] | S: [5]
# Pvl: 62.697
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [4.00012084]
#  [5.00015076]
#  [4.19907404]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [ 3.00000000e+00]
#  [-1.20842914e-04]
#  [-1.50758853e-04]
#  [ 1.80092596e+00]]
# [val : 180.0926, idx : 5]
# omega: -7.5338240612219565
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.09259577430896 ]
# J: 0
# If Lambda* in [ -inf , 180.09259577430896 ]
# 172.558771713087
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.09259577430896 ]
# 172.558771713087
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.09259577430896 , inf ]
# -7.5338240612219565
# Condition to refute: Lambda* < 7.534
# Lambda is 30 and the possible lower bound is 7.5338240612219565
# Possible interval: [ 7.5338240612219565 ,  inf ]
# S0: [0, 1, 2] | S1: [3, 4] | S: [5]
# Pvl: 62.697
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 4] | S1: [3] | S: [5]
# Pvl: 34.78
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [3.99979984]
#  [0.        ]
#  [4.19888421]]
# [[1.00000000e+00]
#  [2.00000000e+00]
#  [3.00000000e+00]
#  [2.00162125e-04]
#  [5.00000000e+00]
#  [1.80111579e+00]]
# [val : 180.1116, idx : 5]
# omega: -7.543461056899574
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.11157941567637 ]
# J: 0
# If Lambda* in [ -inf , 180.11157941567637 ]
# 172.56811835877681
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.11157941567637 ]
# 172.56811835877681
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.11157941567637 , inf ]
# -7.543461056899574
# Condition to refute: Lambda* < 7.543
# Lambda is 30 and the possible lower bound is 7.543461056899574
# Possible interval: [ 7.543461056899574 ,  inf ]
# S0: [0, 1, 2, 4] | S1: [3] | S: [5]
# Pvl: 34.78
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 3] | S1: [4] | S: [5]
# Pvl: 34.03
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [5.0004469 ]
#  [4.20401914]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [ 3.00000000e+00]
#  [ 4.00000000e+00]
#  [-4.46899623e-04]
#  [ 1.79598086e+00]]
# [val : 179.5981, idx : 5]
# omega: -7.503413261555707
# J0: 0
# Lambda: 30
# First interval [ -inf , 179.59808646464168 ]
# J: 0
# If Lambda* in [ -inf , 179.59808646464168 ]
# 172.09467320308596
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 179.59808646464168 ]
# 172.09467320308596
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 179.59808646464168 , inf ]
# -7.503413261555707
# Condition to refute: Lambda* < 7.503
# Lambda is 30 and the possible lower bound is 7.503413261555707
# Possible interval: [ 7.503413261555707 ,  inf ]
# S0: [0, 1, 2, 3] | S1: [4] | S: [5]
# Pvl: 34.03
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 3, 4] | S1: [] | S: [5]
# Pvl: 6.113
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [4.19950141]]
# [[1.        ]
#  [2.        ]
#  [3.        ]
#  [4.        ]
#  [5.        ]
#  [1.80049859]]
# [val : 180.0499, idx : 5]
# omega: -7.5611963611772754
# J0: 0
# Lambda: 30
# First interval [ -inf , 180.04985874027798 ]
# J: 0
# If Lambda* in [ -inf , 180.04985874027798 ]
# 172.4886623791007
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: 0
# If Lambda* in [ -inf , 180.04985874027798 ]
# 172.4886623791007
# No condition, we have Omega + Sum > 0
# Lambda is 30 and the possible upper bound is inf
# Lambda is 30 and the possible lower bound is -inf
# Possible interval: [ -inf ,  inf ]
# J: -1
# If Lambda* in [ 180.04985874027798 , inf ]
# -7.5611963611772754
# Condition to refute: Lambda* < 7.561
# Lambda is 30 and the possible lower bound is 7.5611963611772754
# Possible interval: [ 7.5611963611772754 ,  inf ]
# S0: [0, 1, 2, 3, 4] | S1: [] | S: [5]
# Pvl: 6.113
#  [ -inf , inf ]
#
#
# S0: [1, 2, 3, 4, 5] | S1: [0] | S: []
# Pvl: 37.5
#
# [[0.99998413]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# [[1.58673363e-05]
#  [2.00000000e+00]
#  [3.00000000e+00]
#  [4.00000000e+00]
#  [5.00000000e+00]
#  [6.00000000e+00]]
# []
# omega: 0.001570866548483707
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.001570866548483707 constant 2: 0.0
# S0: [1, 2, 3, 4, 5] | S1: [0] | S: []
# Pvl: 37.5
#  [ -inf , inf ]
#
#
# S0: [0, 2, 3, 4, 5] | S1: [1] | S: []
# Pvl: 37.25
#
# [[0.       ]
#  [1.9992711]
#  [0.       ]
#  [0.       ]
#  [0.       ]
#  [0.       ]]
# [[1.00000000e+00]
#  [7.28899472e-04]
#  [3.00000000e+00]
#  [4.00000000e+00]
#  [5.00000000e+00]
#  [6.00000000e+00]]
# []
# omega: 0.0714326795704614
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.0714326795704614 constant 2: 0.0
# S0: [0, 2, 3, 4, 5] | S1: [1] | S: []
# Pvl: 37.25
#  [ -inf , inf ]
#
#
# S0: [0, 1, 3, 4, 5] | S1: [2] | S: []
# Pvl: 36.833
#
# [[0.        ]
#  [0.        ]
#  [3.00000251]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [-2.51481302e-06]
#  [ 4.00000000e+00]
#  [ 5.00000000e+00]
#  [ 6.00000000e+00]]
# []
# omega: 0.0002590257478010116
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.0002590257478010116 constant 2: 0.0
# S0: [0, 1, 3, 4, 5] | S1: [2] | S: []
# Pvl: 36.833
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 4, 5] | S1: [3] | S: []
# Pvl: 36.25
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [3.99991252]
#  [0.        ]
#  [0.        ]]
# [[1.00000000e+00]
#  [2.00000000e+00]
#  [3.00000000e+00]
#  [8.74765613e-05]
#  [5.00000000e+00]
#  [6.00000000e+00]]
# []
# omega: 0.008397757535235861
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.008397757535235861 constant 2: 0.0
# S0: [0, 1, 2, 4, 5] | S1: [3] | S: []
# Pvl: 36.25
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 3, 5] | S1: [4] | S: []
# Pvl: 35.5
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [4.99213183]
#  [0.        ]]
# [[1.        ]
#  [2.        ]
#  [3.        ]
#  [4.        ]
#  [0.00786817]
#  [6.        ]]
# []
# omega: 0.7475382531340866
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.7475382531340866 constant 2: 0.0
# S0: [0, 1, 2, 3, 5] | S1: [4] | S: []
# Pvl: 35.5
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 3, 4] | S1: [5] | S: []
# Pvl: 34.583
#
# [[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [6.00336483]]
# [[ 1.00000000e+00]
#  [ 2.00000000e+00]
#  [ 3.00000000e+00]
#  [ 4.00000000e+00]
#  [ 5.00000000e+00]
#  [-3.36482921e-03]]
# []
# omega: 0.3566832186868645
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.3566832186868645 constant 2: 0.0
# S0: [0, 1, 2, 3, 4] | S1: [5] | S: []
# Pvl: 34.583
#  [ -inf , inf ]
#
#
# S0: [0, 1, 2, 3, 4, 5] | S1: [] | S: []
# Pvl: 7.583
#
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]
# [[1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]]
# []
# omega: 0.0
# J0: -1
# Lambda: 30
# Leaf Node
# Calc bound leaf constant1: 0.0 constant 2: 0.0
# S0: [0, 1, 2, 3, 4, 5] | S1: [] | S: []
# Pvl: 7.583
#  [ -inf , inf ]
#
#
# [ -inf , inf ]
